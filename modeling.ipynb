# %% [markdown]
# # Importing the libraries

# %%
import os
import pandas as pd
import numpy as np

import spotipy
from spotipy.oauth2 import SpotifyOAuth,SpotifyClientCredentials
import yaml
import re
from tqdm import tqdm
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder

# %%
stream= open("spotify/spotify.yaml")
spotify_details = yaml.safe_load(stream)
auth_manager = SpotifyClientCredentials(client_id=spotify_details['Client_id'],
                                        client_secret=spotify_details['client_secret'])
sp = spotipy.client.Spotify(auth_manager=auth_manager)

# %% [markdown]
# # Importing the dataset

# %%
dtypes = {'track_uri': 'object', 'artist_uri': 'object', 'album_uri': 'object', 'danceability': 'float16', 'energy': 'float16', 'key': 'float16',
               'loudness': 'float16', 'mode': 'float16', 'speechiness': 'float16', 'acousticness': 'float16', 'instrumentalness': 'float16',
               'liveness': 'float16', 'valence': 'float16', 'tempo': 'float16', 'duration_ms': 'float32', 'time_signature': 'float16',
               'Track_release_date': 'int8', 'Track_pop': 'int8', 'Artist_pop': 'int8', 'genres': 'object'}
try:
    df=pd.read_csv('data/final_processed_data.csv',dtype=dtypes)
except:
    print('Failed to load dataset')
    df=pd.read_csv('data/final_processed_data.csv',dtype=dtypes)

# %%
df.rename(columns = {'genres':'Artist_genres'}, inplace = True)

# %%
df.head()
df.dtypes
# Out:
# track_uri              object
# artist_uri             object
# album_uri              object
# danceability          float16
# energy                float16
# key                   float16
# loudness              float16
# mode                  float16
# speechiness           float16
# acousticness          float16
# instrumentalness      float16
# liveness              float16
# valence               float16
# tempo                 float16
# duration_ms           float32
# time_signature        float16
# Artist_genres          object
# Track_pop                int8
# Artist_pop               int8
# Track_release_date       int8
# dtype: object

# %% [markdown]
# # Test

# %% [markdown]
# Extract playlist tracks and artist uri

# %%
user_det=sp.user("316yiwiyxgcdn5m5eurpnlc4dcda")

# %%
user_det
# Out:
# {'display_name': 'Mayank Shetty',
#  'external_urls': {'spotify': 'https://open.spotify.com/user/316yiwiyxgcdn5m5eurpnlc4dcda'},
#  'href': 'https://api.spotify.com/v1/users/316yiwiyxgcdn5m5eurpnlc4dcda',
#  'id': '316yiwiyxgcdn5m5eurpnlc4dcda',
#  'images': [{'url': 'https://platform-lookaside.fbsbx.com/platform/profilepic/?asid=1286400288088541&height=50&width=50&ext=1710994938&hash=AfpbjC1hCPr57EbdSXgjFt2jU7A6cxjJ_4QldqyQomDPyA',
#    'height': 64,
#    'width': 64},
#   {'url': 'https://platform-lookaside.fbsbx.com/platform/profilepic/?asid=1286400288088541&height=300&width=300&ext=1710994938&hash=AfpwecPRNcUd9XnG9VHgNRFnigE_JKED227TWHClA13GVg',
#    'height': 300,
#    'width': 300}],
#  'type': 'user',
#  'uri': 'spotify:user:316yiwiyxgcdn5m5eurpnlc4dcda',
#  'followers': {'href': None, 'total': 7}}

# %%
def get_IDs (user, playlist_id):
 track_ids = []
 artist_id = []
 playlist=sp.user_playlist (user, playlist_id)
 for item in playlist['tracks']['items']:
  track=item['track']
  track_ids.append(track['id'])
  artist=item['track']['artists']
  artist_id.append(artist[0]['id'])
 return track_ids,artist_id


track_ids,artist_id = get_IDs ('316yiwiyxgcdn5m5eurpnlc4dcda', '37i9dQZF1DXaQm3ZVg9Z2X') 
print (len(track_ids))
print (len(artist_id))
# Out:
# 50
# 50

# %% [markdown]
# Getting uri using the spotipy api and preprocessing

# %%
artist_id_uni=list(set(artist_id))
track_ids_uni=list(set(track_ids))

# %%
audio_features=pd.DataFrame()
for i in tqdm(range(0,len(track_ids_uni),25)):
    try:
     track_feature = sp.audio_features(track_ids_uni[i:i+25])
     track_df = pd.DataFrame(track_feature)
     audio_features=pd.concat([audio_features,track_df],axis=0)
    except Exception as e:
        print(e)
        continue
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  6.28it/s]

# %%
track_=pd.DataFrame()
for i in tqdm(range(0,len(track_ids_uni),25)):
    try:
        track_features = sp.tracks(track_ids_uni[i:i+25])
        for x in range(len(track_features['tracks'])):
            track_pop=pd.DataFrame([track_ids_uni[i+x]],columns=['Track_uri'])
            track_pop['Track_release_date']=track_features['tracks'][x]['album']['release_date']
            track_pop['Track_pop'] = track_features['tracks'][x]["popularity"]
            track_pop['Artist_uri']=track_features['tracks'][x]['artists'][0]['id']
            track_pop['Album_uri']=track_features['tracks'][x]['album']['id']
            track_=pd.concat([track_,track_pop],axis=0)
    except Exception as e:
        print(e)
        continue
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  2.44it/s]

# %%
artist_=pd.DataFrame()
for i in tqdm(range(0,len(artist_id_uni),25)):
    try:
        artist_features = sp.artists(artist_id_uni[i:i+25])
        for x in range(len(artist_features['artists'])):
            artist_df=pd.DataFrame([artist_id_uni[i+x]],columns=['Artist_uri'])
            artist_pop = artist_features['artists'][x]["popularity"]
            artist_genres = artist_features['artists'][x]["genres"]
            artist_df["Artist_pop"] = artist_pop
            if artist_genres: 
                artist_df["genres"] = " ".join([re.sub(' ','_',i) for i in artist_genres])
            else:
              artist_df["genres"] = "unknown"
            artist_=pd.concat([artist_,artist_df],axis=0)
    except Exception as e:
        print(e)
        continue
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  4.72it/s]

# %%
test=pd.DataFrame(track_,columns=['Track_uri','Artist_uri','Album_uri'])

# %%
test.rename(columns = {'Track_uri':'track_uri','Artist_uri':'artist_uri','Album_uri':'album_uri'}, inplace = True)

# %%
audio_features.drop(columns=['type','uri','track_href','analysis_url'],axis=1,inplace=True)

# %%
test = pd.merge(test,audio_features, left_on = "track_uri", right_on= "id",how = 'outer')
test = pd.merge(test,track_, left_on = "track_uri", right_on= "Track_uri",how = 'outer')
test = pd.merge(test,artist_, left_on = "artist_uri", right_on= "Artist_uri",how = 'outer')

# %%
del audio_features,track_,artist_

# %%
test.rename(columns = {'genres':'Artist_genres'}, inplace = True)

# %%
test.drop(columns=['Track_uri','Artist_uri_x','Artist_uri_y','Album_uri','id'],axis=1,inplace=True)

# %%
test
# Out:
#                  track_uri              artist_uri               album_uri  \
# 0   2w3eXFL86RgxGtDr8bzwgK  4gzpq5DPGxSnKTe4SA8HAU  4E7bV0pzG0LciBSWTszra6
# 1   6V6goat94tTJOWXXKZstNX  4gzpq5DPGxSnKTe4SA8HAU  0CE9VXSH70pz4BQzMPm9gO
# 2   4hf0hL4kWyjWztZzVsM39V  4gzpq5DPGxSnKTe4SA8HAU  0RHX9XECH8IVI3LNgWDpmQ
# 3   0u35Dpz37TY2M2j20RUdMf  4gzpq5DPGxSnKTe4SA8HAU  0RHX9XECH8IVI3LNgWDpmQ
# 4   2DHgvPQD1jApRnT1DBZdrS  4gzpq5DPGxSnKTe4SA8HAU  6ZG5lRT77aJ3btmArcykra
# 5   0BCPKOYdS2jbQ8iyB56Zns  4gzpq5DPGxSnKTe4SA8HAU  0RHX9XECH8IVI3LNgWDpmQ
# 6   1ZqHjApl3pfzwjweTfMi0g  4gzpq5DPGxSnKTe4SA8HAU  1CEODgTmTwLyabvwd7HBty
# 7   0R8P9KfGJCDULmlEoBagcO  4gzpq5DPGxSnKTe4SA8HAU  6ZG5lRT77aJ3btmArcykra
# 8   7KolrFGhfDi1JTSgQBT5sI  4gzpq5DPGxSnKTe4SA8HAU  0RHX9XECH8IVI3LNgWDpmQ
# 9   75JFxkI2RXiU7L9VXzMkle  4gzpq5DPGxSnKTe4SA8HAU  0RHX9XECH8IVI3LNgWDpmQ
# 10  0qksx8mV28lztYIZ1om8ml  4gzpq5DPGxSnKTe4SA8HAU  6ZG5lRT77aJ3btmArcykra
# 11  03T4ttRCiLXST6MZjeMwmR  4gzpq5DPGxSnKTe4SA8HAU  2FeyIYDDAQqcOJKOKhvHdr
# 12  3AJwUDP919kvQ9QcozQPxg  4gzpq5DPGxSnKTe4SA8HAU  6ZG5lRT77aJ3btmArcykra
# 13  31L9yLXSj6LpCFupyMV6CR  4gzpq5DPGxSnKTe4SA8HAU  3cfAM8b8KqJRoIzt3zLKqw
# 14  7D0RhFcb3CrfPuTJ0obrod  4gzpq5DPGxSnKTe4SA8HAU  6ZG5lRT77aJ3btmArcykra
# 15  3E3zYgQul8EaJioNvD2tv9  4gzpq5DPGxSnKTe4SA8HAU  2FeyIYDDAQqcOJKOKhvHdr
# 16  6Tb7Zfo4PcSiS4TqQ4NnTh  4gzpq5DPGxSnKTe4SA8HAU  2FeyIYDDAQqcOJKOKhvHdr
# 17  7LVHVU3tWfcxj5aiPFEW4Q  4gzpq5DPGxSnKTe4SA8HAU  4E7bV0pzG0LciBSWTszra6
# 18  3pcPPhPAiurm2Ior11SHrz  4gzpq5DPGxSnKTe4SA8HAU  2FeyIYDDAQqcOJKOKhvHdr
# 19  2RZ8SjEJYJHZ8YCUzls77w  4gzpq5DPGxSnKTe4SA8HAU  4JYjZh7R8F7Na5x1lVqOl9
# 20  0939D7aT18uBDS2MTjWzct  4gzpq5DPGxSnKTe4SA8HAU  6wiPmk3powmcz3G7zr6krg
# 21  2nvC4i2aMo4CzRjRflysah  4gzpq5DPGxSnKTe4SA8HAU  0RHX9XECH8IVI3LNgWDpmQ
# 22  2XiSB3m4WSkxD3xIUrYHfV  4gzpq5DPGxSnKTe4SA8HAU  573eP6oKtAJDqnpco7Fn9c
# 23  4HXOBjwv2RnLpGG4xWOO6N  4gzpq5DPGxSnKTe4SA8HAU  2R7iJz5uaHjLEVnMkloO18
# 24  6uJwPeBGb3swi85TSr9iIz  4gzpq5DPGxSnKTe4SA8HAU  0CE9VXSH70pz4BQzMPm9gO
# 25  0FMjqbY3aWo1QDbo3GwXib  4gzpq5DPGxSnKTe4SA8HAU  2G4AUqfwxcV1UdQjm2ouYr
# 26  3HWDWyIqWuLsTHECx9DvXF  4gzpq5DPGxSnKTe4SA8HAU  3cfAM8b8KqJRoIzt3zLKqw
# 27  4TcCbhzD4caTdkkvkS45oa  4gzpq5DPGxSnKTe4SA8HAU  574iaZA34RiT9rM1F2s2IM
# 28  6qt0IWS8y6yGR6gNTEmQzj  4gzpq5DPGxSnKTe4SA8HAU  573eP6oKtAJDqnpco7Fn9c
# 29  4cGqn0E8JCSY9gQllQj4Mf  4gzpq5DPGxSnKTe4SA8HAU  06mXfvDsRZNfnsGZvX2zpb
# 30  7mGJlNOAOmJ5ptkmujg1Gv  4gzpq5DPGxSnKTe4SA8HAU  19CvkGjYpifkdwgVJSbog2
# 31  7clUVcSOtkNWa58Gw5RfD4  4gzpq5DPGxSnKTe4SA8HAU  4E7bV0pzG0LciBSWTszra6
# 32  6U8VHaQxzECez4TSt0nmiP  4gzpq5DPGxSnKTe4SA8HAU  573eP6oKtAJDqnpco7Fn9c
# 33  6mf7BNgXs8JipPr2QILnyN  4gzpq5DPGxSnKTe4SA8HAU  2FeyIYDDAQqcOJKOKhvHdr
# 34  7HBnZdg7fIQwqMhQhci0VV  4gzpq5DPGxSnKTe4SA8HAU  0CE9VXSH70pz4BQzMPm9gO
# 35  4Y9lVjRD82aJOQ2v13UIoF  4gzpq5DPGxSnKTe4SA8HAU  19CvkGjYpifkdwgVJSbog2
# 36  0h9fnCSnbUgOEgibnQByFv  4gzpq5DPGxSnKTe4SA8HAU  2FeyIYDDAQqcOJKOKhvHdr
# 37  6f49kbOuQSOsStBpyGvQfA  4gzpq5DPGxSnKTe4SA8HAU  3cfAM8b8KqJRoIzt3zLKqw
# 38  3RiPr603aXAoi4GHyXx0uy  4gzpq5DPGxSnKTe4SA8HAU  3cfAM8b8KqJRoIzt3zLKqw
# 39  6nek1Nin9q48AVZcWs9e9D  4gzpq5DPGxSnKTe4SA8HAU  2R7iJz5uaHjLEVnMkloO18
# 40  6P2Y4KnF2x8uwZV2cZWA8t  4gzpq5DPGxSnKTe4SA8HAU  0G0WNcM706ASd6n7UxXuKu
# 41  1uKzAldJYlwje9HstlwTie  4gzpq5DPGxSnKTe4SA8HAU  3MVb2CWB36x7VwYo5sZmf2
# 42  0ZlVUhjO8c0bOx1D2Btznf  4gzpq5DPGxSnKTe4SA8HAU  2FeyIYDDAQqcOJKOKhvHdr
# 43  33koOQs551ijjVmLbmrcDc  4gzpq5DPGxSnKTe4SA8HAU  573eP6oKtAJDqnpco7Fn9c
# 44  2U8g9wVcUu9wsg6i7sFSv8  4gzpq5DPGxSnKTe4SA8HAU  2R7iJz5uaHjLEVnMkloO18
# 45  4GKk1uNzpxIptBuaY97Dkj  4gzpq5DPGxSnKTe4SA8HAU  2G4AUqfwxcV1UdQjm2ouYr
# 46  3FeVmId7tL5YN8B7R3imoM  4gzpq5DPGxSnKTe4SA8HAU  39McjovZ3M6n5SFtNmWTdp
# 47  1yqMgZNrevsWMLWfO2PRp5  4gzpq5DPGxSnKTe4SA8HAU  2R7iJz5uaHjLEVnMkloO18
# 48  23khhseCLQqVMCIT1WMAns  4gzpq5DPGxSnKTe4SA8HAU  2G4AUqfwxcV1UdQjm2ouYr
# 49  1dNIEtp7AY3oDAKCGg2XkH  69GGBxA162lTqCwzJG5jLp  7IzpJkWQqgz1BTutQvSitX
#
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.566   0.459    1    -9.488     1       0.0289      0.327000
# 1          0.352   0.711    5    -6.412     1       0.0334      0.157000
# 2          0.611   0.556    9    -5.761     1       0.0288      0.175000
# 3          0.262   0.482    5    -7.750     0       0.0294      0.036400
# 4          0.495   0.525    7    -9.342     0       0.0301      0.396000
# 5          0.577   0.749    5    -7.215     0       0.0279      0.599000
# 6          0.330   0.580    1    -7.875     0       0.0374      0.061400
# 7          0.565   0.546   11    -7.496     0       0.0314      0.189000
# 8          0.277   0.797    0    -5.660     1       0.0385      0.586000
# 9          0.557   0.442    5    -7.224     1       0.0243      0.731000
# 10         0.396   0.803    4    -6.186     1       0.0487      0.033400
# 11         0.503   0.808   11    -5.051     0       0.0451      0.025800
# 12         0.429   0.661   11    -7.227     1       0.0281      0.002390
# 13         0.479   0.717    7    -5.459     1       0.0605      0.048800
# 14         0.371   0.268    1   -10.506     1       0.0281      0.748000
# 15         0.476   0.180    5   -17.499     1       0.0346      0.943000
# 16         0.146   0.216    9   -12.302     1       0.0399      0.939000
# 17         0.209   0.417    3    -8.740     1       0.0338      0.164000
# 18         0.633   0.180    1   -19.540     1       0.0340      0.931000
# 19         0.550   0.796    7    -7.262     1       0.0378      0.001070
# 20         0.507   0.828   10    -6.023     1       0.0449      0.007110
# 21         0.424   0.588    9    -5.455     1       0.0278      0.055300
# 22         0.515   0.851    9    -8.174     0       0.0689      0.064400
# 23         0.420   0.690    9    -6.221     0       0.0347      0.003850
# 24         0.624   0.824    6    -5.501     1       0.0445      0.016700
# 25         0.495   0.502    5    -9.307     1       0.0259      0.012700
# 26         0.559   0.841    0    -5.584     1       0.0332      0.000315
# 27         0.614   0.680    5    -7.840     0       0.0425      0.016800
# 28         0.433   0.922    8    -6.800     1       0.1200      0.123000
# 29         0.592   0.342    0    -8.930     1       0.0339      0.193000
# 30         0.256   0.625    3    -7.530     1       0.0348      0.005340
# 31         0.514   0.898   11    -6.765     0       0.0577      0.004880
# 32         0.536   0.486    1    -9.431     0       0.0370      0.304000
# 33         0.503   0.594    7    -7.095     1       0.0263      0.002760
# 34         0.501   0.639    5    -6.591     1       0.0357      0.399000
# 35         0.428   0.948    5    -4.655     0       0.0934      0.005370
# 36         0.512   0.452    2    -8.991     1       0.0292      0.775000
# 37         0.449   0.920   11    -4.982     1       0.0737      0.002100
# 38         0.491   0.693    0    -6.487     0       0.0377      0.211000
# 39         0.449   0.585    5    -6.761     1       0.0268      0.050900
# 40         0.289   0.263    2   -10.880     1       0.0297      0.652000
# 41         0.369   0.295    4   -12.779     1       0.0351      0.657000
# 42         0.401   0.834    7    -7.727     1       0.0550      0.000114
# 43         0.223   0.439   11   -10.456     1       0.0312      0.447000
# 44         0.425   0.732    9    -6.883     1       0.0396      0.001940
# 45         0.548   0.475    1   -12.420     1       0.0355      0.615000
# 46         0.588   0.701    9    -6.390     1       0.0402      0.008130
# 47         0.430   0.740   10    -7.072     1       0.0375      0.021200
# 48         0.738   0.482    6    -8.917     0       0.0402      0.026600
# 49         0.607   0.649   11    -6.695     0       0.0362      0.030600
#
#     instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0           0.000253    0.2020   0.1510  116.916       285345               4
# 1           0.701000    0.0683   0.4220   73.161       274587               4
# 2           0.000071    0.0359   0.2520  126.532       297307               4
# 3           0.000189    0.1100   0.0630  170.968       318627               4
# 4           0.007360    0.0961   0.2490  154.466       256467               4
# 5           0.011500    0.1830   0.2550  130.970       307880               4
# 6           0.001290    0.1150   0.1100   76.093       222653               4
# 7           0.001500    0.1700   0.1950  139.757       273427               4
# 8           0.341000    0.2210   0.2600  177.004       238333               3
# 9           0.000015    0.1100   0.2130  146.277       309600               4
# 10          0.000000    0.0688   0.2860  116.705       304200               3
# 11          0.001490    0.5570   0.2820  107.973       197533               4
# 12          0.000121    0.2340   0.2850  173.372       266773               4
# 13          0.000333    0.1020   0.2530  163.989       405320               4
# 14          0.051700    0.1040   0.1650  102.617       227093               3
# 15          0.235000    0.1380   0.2360  134.025       146947               5
# 16          0.540000    0.0773   0.0341   78.045       151093               4
# 17          0.001960    0.1130   0.1240  138.178       295533               4
# 18          0.801000    0.5130   0.2000  116.981       298320               4
# 19          0.000012    0.1230   0.5100   89.876       216493               4
# 20          0.000024    0.2610   0.4890  178.032       211295               4
# 21          0.000005    0.2980   0.1930  144.636       226680               4
# 22          0.000139    0.9190   0.5880  115.665       258613               4
# 23          0.015000    0.2870   0.2370   85.014       239216               4
# 24          0.000290    0.1380   0.3660   97.012       276907               4
# 25          0.689000    0.0680   0.0394   97.546       216627               3
# 26          0.437000    0.0816   0.1470  105.009       229093               4
# 27          0.000560    0.1180   0.3470  153.937       192395               4
# 28          0.000005    0.9300   0.5000  138.203       234027               3
# 29          0.002450    0.1100   0.1550  130.953       241595               4
# 30          0.003860    0.1790   0.2010  140.351       327467               4
# 31          0.034500    0.0746   0.3530  123.067       287907               4
# 32          0.000479    0.9450   0.1250   72.727       255853               4
# 33          0.010200    0.1090   0.1680  108.900       257547               4
# 34          0.850000    0.0990   0.0789  120.040       391414               4
# 35          0.000001    0.3710   0.2190  138.015       251067               4
# 36          0.081800    0.0650   0.2350  124.103       258533               4
# 37          0.016700    0.3340   0.0772  122.984       223773               4
# 38          0.000007    0.3250   0.4120   90.027       258267               4
# 39          0.000087    0.0833   0.2120  139.631       278719               4
# 40          0.155000    0.1030   0.0736  133.585       618960               4
# 41          0.000015    0.1070   0.2110   92.226       171373               4
# 42          0.849000    0.3730   0.1630  172.009       340280               4
# 43          0.014100    0.9260   0.1190  165.899       252467               4
# 44          0.010300    0.1710   0.3330  117.980       240796               4
# 45          0.808000    0.0944   0.0349  126.974       294667               4
# 46          0.000000    0.2000   0.4430  104.988       228000               4
# 47          0.001650    0.3300   0.0948  137.978       285160               4
# 48          0.621000    0.1060   0.3520   93.457       285014               4
# 49          0.000025    0.1740   0.5050  102.996       247627               4
#
#    Track_release_date  Track_pop  Artist_pop       Artist_genres
# 0          2005-06-07         65          88  permanent_wave pop
# 1          2017-07-13         59          88  permanent_wave pop
# 2          2002-08-08         67          88  permanent_wave pop
# 3          2002-08-08         68          88  permanent_wave pop
# 4          2000-07-10         65          88  permanent_wave pop
# 5          2002-08-08         85          88  permanent_wave pop
# 6          2008-05-26         70          88  permanent_wave pop
# 7          2000-07-10         76          88  permanent_wave pop
# 8          2002-08-08         59          88  permanent_wave pop
# 9          2002-08-08         89          88  permanent_wave pop
# 10         2000-07-10         70          88  permanent_wave pop
# 11         2019-11-22         70          88  permanent_wave pop
# 12         2000-07-10         94          88  permanent_wave pop
# 13         2015-12-04         72          88  permanent_wave pop
# 14         2000-07-10         90          88  permanent_wave pop
# 15         2019-11-22         59          88  permanent_wave pop
# 16         2019-11-22         62          88  permanent_wave pop
# 17         2005-06-07         87          88  permanent_wave pop
# 18         2019-11-22         62          88  permanent_wave pop
# 19         2020-12-21         63          88  permanent_wave pop
# 20         2021-05-07         74          88  permanent_wave pop
# 21         2002-08-08         78          88  permanent_wave pop
# 22         2016-12-16         61          88  permanent_wave pop
# 23         2011-10-24         73          88  permanent_wave pop
# 24         2017-07-13         63          88  permanent_wave pop
# 25         2014-05-19         68          88  permanent_wave pop
# 26         2015-12-04         65          88  permanent_wave pop
# 27         2022-07-06         65          88  permanent_wave pop
# 28         2016-12-16         66          88  permanent_wave pop
# 29         2021-10-15         75          88  permanent_wave pop
# 30         2018-12-07         62          88  permanent_wave pop
# 31         2005-06-07         75          88  permanent_wave pop
# 32         2016-12-16         62          88  permanent_wave pop
# 33         2019-11-22         63          88  permanent_wave pop
# 34         2017-07-13         59          88  permanent_wave pop
# 35         2018-12-07         63          88  permanent_wave pop
# 36         2019-11-22         66          88  permanent_wave pop
# 37         2015-12-04         70          88  permanent_wave pop
# 38         2015-12-04         86          88  permanent_wave pop
# 39         2011-10-24         87          88  permanent_wave pop
# 40         2021-07-23         61          88  permanent_wave pop
# 41         1999-10-11         64          88  permanent_wave pop
# 42         2019-11-22         60          88  permanent_wave pop
# 43         2016-12-16         60          88  permanent_wave pop
# 44         2011-10-24         74          88  permanent_wave pop
# 45         2014-05-19         67          88  permanent_wave pop
# 46         2021-09-24         81          88  permanent_wave pop
# 47         2011-10-24         74          88  permanent_wave pop
# 48         2014-05-19         76          88  permanent_wave pop
# 49         2017-02-22         76          79                 pop

# %%
test.dropna(axis=0,inplace=True)

# %% [markdown]
# Dividing popularity in buckets of 5, release date in buckets of 50 yrs.

# %%
test['Track_pop'] = test['Track_pop'].apply(lambda x: int(x/5))
test['Artist_pop'] = test['Artist_pop'].apply(lambda x: int(x/5))
test['Track_release_date'] = test['Track_release_date'].apply(lambda x: x.split('-')[0])
test['Track_release_date']=test['Track_release_date'].astype('int16')
test['Track_release_date'] = test['Track_release_date'].apply(lambda x: int(x/50))

# %% [markdown]
# Changind datatypes

# %%
test[['danceability', 'energy', 'key','loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness','liveness', 'valence', 'tempo', 'time_signature']]=test[['danceability', 'energy', 'key','loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness','liveness', 'valence', 'tempo','time_signature']].astype('float16')
test[['duration_ms']]=test[['duration_ms']].astype('float32')
test[['Track_release_date', 'Track_pop', 'Artist_pop']]=test[['Track_release_date', 'Track_pop', 'Artist_pop']].astype('int8')

# %%
df=pd.read_csv("Streamlit/data/streamlit_data.csv")

# %%
currentdf=len(df)

# %%
df.dropna(axis=0,inplace=True)

# %%
print('{} New Tracks Found'.format(len(df)-currentdf))
# Out:
# 0 New Tracks Found

# %%
len(df)
# Out:
# 113384

# %%
df = df[~df['track_uri'].isin(test['track_uri'].values)]

# %%
test.head()
# Out:
#                 track_uri              artist_uri               album_uri  \
# 0  2w3eXFL86RgxGtDr8bzwgK  4gzpq5DPGxSnKTe4SA8HAU  4E7bV0pzG0LciBSWTszra6
# 1  6V6goat94tTJOWXXKZstNX  4gzpq5DPGxSnKTe4SA8HAU  0CE9VXSH70pz4BQzMPm9gO
# 2  4hf0hL4kWyjWztZzVsM39V  4gzpq5DPGxSnKTe4SA8HAU  0RHX9XECH8IVI3LNgWDpmQ
# 3  0u35Dpz37TY2M2j20RUdMf  4gzpq5DPGxSnKTe4SA8HAU  0RHX9XECH8IVI3LNgWDpmQ
# 4  2DHgvPQD1jApRnT1DBZdrS  4gzpq5DPGxSnKTe4SA8HAU  6ZG5lRT77aJ3btmArcykra
#
#    danceability    energy  key  loudness  mode  speechiness  acousticness  \
# 0      0.565918  0.458984  1.0 -9.484375   1.0     0.028900      0.326904
# 1      0.352051  0.710938  5.0 -6.410156   1.0     0.033386      0.156982
# 2      0.610840  0.556152  9.0 -5.761719   1.0     0.028793      0.175049
# 3      0.261963  0.481934  5.0 -7.750000   0.0     0.029404      0.036407
# 4      0.495117  0.524902  7.0 -9.343750   0.0     0.030106      0.395996
#
#    instrumentalness  liveness   valence     tempo  duration_ms  \
# 0          0.000253  0.202026  0.151001  116.9375     285345.0
# 1          0.701172  0.068298  0.422119   73.1875     274587.0
# 2          0.000071  0.035889  0.251953  126.5625     297307.0
# 3          0.000189  0.109985  0.062988  171.0000     318627.0
# 4          0.007359  0.096130  0.249023  154.5000     256467.0
#
#    time_signature  Track_release_date  Track_pop  Artist_pop  \
# 0             4.0                  40         13          17
# 1             4.0                  40         11          17
# 2             4.0                  40         13          17
# 3             4.0                  40         13          17
# 4             4.0                  40         13          17
#
#         Artist_genres
# 0  permanent_wave pop
# 1  permanent_wave pop
# 2  permanent_wave pop
# 3  permanent_wave pop
# 4  permanent_wave pop

# %%
test['Artist_genres'] = test['Artist_genres'].apply(lambda x: x.split(" "))
tfidf = TfidfVectorizer(max_features=3) #max_features=5 
tfidf_matrix = tfidf.fit_transform(test['Artist_genres'].apply(lambda x: " ".join(x)))
genre_df = pd.DataFrame(tfidf_matrix.toarray())
genre_df.columns = ['genre' + "|" + i for i in tfidf.get_feature_names_out()]

# %%
genre_df=genre_df.astype('float16')
test.drop(columns=['Artist_genres'],axis=1,inplace=True)

# %%
test = pd.concat([test.reset_index(drop=True), genre_df.reset_index(drop=True)],axis = 1)

# %%
test.head()
# Out:
#                 track_uri              artist_uri               album_uri  \
# 0  2w3eXFL86RgxGtDr8bzwgK  4gzpq5DPGxSnKTe4SA8HAU  4E7bV0pzG0LciBSWTszra6
# 1  6V6goat94tTJOWXXKZstNX  4gzpq5DPGxSnKTe4SA8HAU  0CE9VXSH70pz4BQzMPm9gO
# 2  4hf0hL4kWyjWztZzVsM39V  4gzpq5DPGxSnKTe4SA8HAU  0RHX9XECH8IVI3LNgWDpmQ
# 3  0u35Dpz37TY2M2j20RUdMf  4gzpq5DPGxSnKTe4SA8HAU  0RHX9XECH8IVI3LNgWDpmQ
# 4  2DHgvPQD1jApRnT1DBZdrS  4gzpq5DPGxSnKTe4SA8HAU  6ZG5lRT77aJ3btmArcykra
#
#    danceability    energy  key  loudness  mode  speechiness  acousticness  \
# 0      0.565918  0.458984  1.0 -9.484375   1.0     0.028900      0.326904
# 1      0.352051  0.710938  5.0 -6.410156   1.0     0.033386      0.156982
# 2      0.610840  0.556152  9.0 -5.761719   1.0     0.028793      0.175049
# 3      0.261963  0.481934  5.0 -7.750000   0.0     0.029404      0.036407
# 4      0.495117  0.524902  7.0 -9.343750   0.0     0.030106      0.395996
#
#    ...  liveness   valence     tempo  duration_ms  time_signature  \
# 0  ...  0.202026  0.151001  116.9375     285345.0             4.0
# 1  ...  0.068298  0.422119   73.1875     274587.0             4.0
# 2  ...  0.035889  0.251953  126.5625     297307.0             4.0
# 3  ...  0.109985  0.062988  171.0000     318627.0             4.0
# 4  ...  0.096130  0.249023  154.5000     256467.0             4.0
#
#    Track_release_date  Track_pop  Artist_pop  genre|permanent_wave  genre|pop
# 0                  40         13          17              0.713867   0.700195
# 1                  40         11          17              0.713867   0.700195
# 2                  40         13          17              0.713867   0.700195
# 3                  40         13          17              0.713867   0.700195
# 4                  40         13          17              0.713867   0.700195
#
# [5 rows x 21 columns]

# %%
test.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# # df

# %%
df['Artist_genres'] = df['Artist_genres'].apply(lambda x: x.split(" "))
tfidf_matrix = tfidf.transform(df['Artist_genres'].apply(lambda x: " ".join(x)))
genre_df = pd.DataFrame(tfidf_matrix.toarray())
genre_df.columns = ['genre' + "|" + i for i in tfidf.get_feature_names_out()]

# %%
genre_df
# Out:
#         genre|permanent_wave  genre|pop
# 0                   0.000000    0.00000
# 1                   0.000000    0.00000
# 2                   0.000000    0.00000
# 3                   0.000000    0.00000
# 4                   0.000000    0.00000
# ...                      ...        ...
# 113346              0.714005    0.70014
# 113347              0.714005    0.70014
# 113348              0.714005    0.70014
# 113349              0.714005    0.70014
# 113350              0.000000    1.00000
#
# [113351 rows x 2 columns]

# %%
genre_df=genre_df.astype('float16')
df.drop(columns=['Artist_genres'],axis=1,inplace=True)

# %%
len(genre_df)
# Out:
# 113351

# %%
df = pd.concat([df.reset_index(drop=True), genre_df.reset_index(drop=True)],axis = 1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_uri', 'artist_uri', 'album_uri', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'time_signature', 'Track_release_date', 'Track_pop', 'Artist_pop',
#        'genre|permanent_wave', 'genre|pop'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['track_uri', 'artist_uri', 'album_uri', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
#        'Track_release_date', 'Track_pop', 'Artist_pop', 'genre|fi_jazzhop',
#        'genre|lo', 'genre|unknown'],
#       dtype='object')

# %%
test.head()
# Out:
#                 track_uri              artist_uri               album_uri  \
# 0  0ZlVUhjO8c0bOx1D2Btznf  4gzpq5DPGxSnKTe4SA8HAU  2FeyIYDDAQqcOJKOKhvHdr
# 1  6P2Y4KnF2x8uwZV2cZWA8t  4gzpq5DPGxSnKTe4SA8HAU  0G0WNcM706ASd6n7UxXuKu
# 2  23khhseCLQqVMCIT1WMAns  4gzpq5DPGxSnKTe4SA8HAU  2G4AUqfwxcV1UdQjm2ouYr
# 3  0FMjqbY3aWo1QDbo3GwXib  4gzpq5DPGxSnKTe4SA8HAU  2G4AUqfwxcV1UdQjm2ouYr
# 4  0qksx8mV28lztYIZ1om8ml  4gzpq5DPGxSnKTe4SA8HAU  6ZG5lRT77aJ3btmArcykra
#
#    danceability    energy       key  loudness  mode  speechiness  \
# 0      0.405748  0.833984  0.636364  0.835386   1.0     0.057165
# 1      0.292573  0.262939  0.181818  0.784946   1.0     0.030867
# 2      0.746754  0.481934  0.545455  0.816408   0.0     0.041779
# 3      0.501131  0.501953  0.454545  0.810166   1.0     0.026917
# 4      0.400806  0.803223  0.363636  0.859982   1.0     0.050630
#
#    acousticness  ...  liveness   valence     tempo  duration_ms  \
# 0      0.000114  ...  0.373047  0.162964  0.726351     0.063589
# 1      0.654473  ...  0.103027  0.073608  0.564295     0.116420
# 2      0.026703  ...  0.106018  0.352051  0.394584     0.053112
# 3      0.012754  ...  0.067993  0.039398  0.412004     0.040147
# 4      0.033520  ...  0.068787  0.285889  0.492768     0.056749
#
#    time_signature  Track_release_date  Track_pop  Artist_pop  \
# 0             0.8                 1.0   0.647059        0.85
# 1             0.8                 1.0   0.647059        0.85
# 2             0.8                 1.0   0.823529        0.85
# 3             0.6                 1.0   0.705882        0.85
# 4             0.6                 1.0   0.764706        0.85
#
#    genre|permanent_wave  genre|pop
# 0              0.713867   0.700195
# 1              0.713867   0.700195
# 2              0.713867   0.700195
# 3              0.713867   0.700195
# 4              0.713867   0.700195
#
# [5 rows x 21 columns]

# %% [markdown]
# # pred

# %%
try:
    df.drop(columns=['genre|unknown'],axis=1,inplace=True)
    test.drop(columns=['genre|unknown'],axis=1,inplace=True)
except:
    print('genre|unknown not found')
# Out:
# genre|unknown not found

# %%
test.columns
# Out:
# Index(['track_uri', 'artist_uri', 'album_uri', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
#        'Track_release_date', 'Track_pop', 'Artist_pop', 'genre|permanent_wave',
#        'genre|pop'],
#       dtype='object')

# %%
test.iloc[:,3:]

# %%
df.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)

# Then, drop the column as usual.

df.drop(["a"], axis=1, inplace=True)

# %%
len(df.columns)
# Out:
# 21

# %% [markdown]
# ## One Hot Encoding
# I was first using OneHotEncoder for "Track_release_date", "Track_pop", and "Artist_pop," but I found no difference in the final result other than high memory usage.

# %%
""" ohe = OneHotEncoder(handle_unknown='ignore')
dummies = pd.DataFrame(ohe.fit_transform(test[['Track_release_date', 'Track_pop', 'Artist_pop']]).toarray(), index=test.index,dtype=int)
column_name = ohe.get_feature_names_out(['Track_release_date', 'Track_pop', 'Artist_pop'])
dummies.columns=column_name
test = pd.concat([test.drop(['Track_release_date', 'Track_pop', 'Artist_pop'], axis=1), dummies], axis=1) """
# Out:
# " ohe = OneHotEncoder(handle_unknown='ignore')\ndummies = pd.DataFrame(ohe.fit_transform(test[['Track_release_date', 'Track_pop', 'Artist_pop']]).toarray(), index=test.index,dtype=int)\ncolumn_name = ohe.get_feature_names_out(['Track_release_date', 'Track_pop', 'Artist_pop'])\ndummies.columns=column_name\ntest = pd.concat([test.drop(['Track_release_date', 'Track_pop', 'Artist_pop'], axis=1), dummies], axis=1) "

# %%
""" ohe2 = OneHotEncoder(categories=ohe.categories_,handle_unknown='ignore')
dummies = pd.DataFrame(ohe2.fit_transform(df[['Track_release_date', 'Track_pop', 'Artist_pop']]).toarray(), index=df.index, dtype=int)
column_name = ohe2.get_feature_names_out(['Track_release_date', 'Track_pop', 'Artist_pop'])
dummies.columns=column_name
df=pd.concat([df.drop(['Track_release_date', 'Track_pop', 'Artist_pop'], axis=1), dummies], axis=1)
 """
# Out:
# " ohe2 = OneHotEncoder(categories=ohe.categories_,handle_unknown='ignore')\ndummies = pd.DataFrame(ohe2.fit_transform(df[['Track_release_date', 'Track_pop', 'Artist_pop']]).toarray(), index=df.index, dtype=int)\ncolumn_name = ohe2.get_feature_names_out(['Track_release_date', 'Track_pop', 'Artist_pop'])\ndummies.columns=column_name\ndf=pd.concat([df.drop(['Track_release_date', 'Track_pop', 'Artist_pop'], axis=1), dummies], axis=1)\n "

# %%
#df.info(memory_usage = "deep")

# %%
#test.loc[:,test.columns.str.startswith('genre')]=test.loc[:,test.columns.str.startswith('genre')].astype('bool')
#df.loc[:,df.columns.str.startswith('genre')]=df.loc[:,df.columns.str.startswith('genre')].astype('bool')

# %% [markdown]
# ## Scaling

# %%
# sc=MinMaxScaler()
# df.iloc[:,3:19]=sc.fit_transform(df.iloc[:,3:19])
# pickle.dump(sc, open('data/sc.sav', 'wb'))

# %%
sc = pickle.load(open('Streamlit/data/sc.sav','rb'))

# %%
test.iloc[:,3:19]=sc.transform(test.iloc[:,3:19])

# %%
df.iloc[:,3:19]=sc.transform(df.iloc[:,3:19])

# %%
test.iloc[:5,3:]
# Out:
#    danceability    energy       key  loudness  mode  speechiness  \
# 0      0.430211  0.731934  0.818182  0.848870   1.0     0.041177
# 1      0.211523  0.416992  0.272727  0.819155   1.0     0.035149
# 2      0.572791  0.458984  0.090909  0.807294   1.0     0.030042
# 3      0.225731  0.438965  1.000000  0.791812   1.0     0.032437
# 4      0.746754  0.481934  0.545455  0.816408   0.0     0.041779
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0      0.001948          0.010320  0.171021  0.333008  0.498311     0.044729
# 1      0.164599          0.001965  0.112976  0.124023  0.583298     0.055106
# 2      0.328217          0.000253  0.202026  0.151001  0.493824     0.053175
# 3      0.448817          0.014127  0.925781  0.119019  0.700486     0.046942
# 4      0.026703          0.622338  0.106018  0.352051  0.394584     0.053112
#
#    time_signature  Track_release_date  Track_pop  Artist_pop  \
# 0             0.8                 1.0   0.764706        0.85
# 1             0.8                 1.0   0.941176        0.85
# 2             0.8                 1.0   0.705882        0.85
# 3             0.8                 1.0   0.647059        0.85
# 4             0.8                 1.0   0.823529        0.85
#
#    genre|permanent_wave  genre|pop
# 0              0.713867   0.700195
# 1              0.713867   0.700195
# 2              0.713867   0.700195
# 3              0.713867   0.700195
# 4              0.713867   0.700195

# %%
playvec=pd.DataFrame(test.sum(axis=0)).T
playvec
# Out:
#                                            track_uri  \
# 0  2U8g9wVcUu9wsg6i7sFSv87LVHVU3tWfcxj5aiPFEW4Q2w...
#
#                                           artist_uri  \
# 0  4gzpq5DPGxSnKTe4SA8HAU4gzpq5DPGxSnKTe4SA8HAU4g...
#
#                                            album_uri danceability     energy  \
# 0  2R7iJz5uaHjLEVnMkloO184E7bV0pzG0LciBSWTszra64E...    23.505578  30.411499
#
#          key   loudness  mode speechiness acousticness  ...   liveness  \
# 0  26.272727  41.497305  35.0      2.0889    11.854809  ...  11.721375
#
#      valence     tempo duration_ms time_signature Track_release_date  \
# 0  12.016418  26.21648     2.48956      39.200001               49.5
#
#    Track_pop Artist_pop genre|permanent_wave genre|pop
# 0  37.235295  42.400001             34.96875   35.3125
#
# [1 rows x 21 columns]

# %%
# playvec2=pd.DataFrame(test.mean(axis=0)).T
# playvec2
# Create an empty DataFrame with the same columns as 'test'
playvec2 = pd.DataFrame(columns=test.columns)
test2=test.copy()
test2.iloc[:,:3]=None
# test
# Set the first three columns to empty strings
# playvec2.loc[:, :3] = ''
# playvec2.loc[0,3:]=pd.DataFrame(test.iloc[:,3:].mean()).T
playvec2=pd.concat([playvec2,pd.DataFrame(test2.mean()).T],axis=0)
# Calculate the mean for the remaining columns and append to the DataFrame
# playvec2 = playvec2.append(test.mean(), ignore_index=True)
# playvec2=pd.concat(playvec2,test.mean())
playvec2
# Out:
#    track_uri  artist_uri  album_uri  danceability   energy       key  \
# 0        NaN         NaN        NaN      0.470112  0.60823  0.525455
#
#    loudness  mode  speechiness  acousticness  ...  liveness   valence  \
# 0  0.829946   0.7     0.041778      0.237096  ...  0.234427  0.240328
#
#      tempo  duration_ms  time_signature  Track_release_date  Track_pop  \
# 0  0.52433     0.049791           0.784                0.99   0.744706
#
#    Artist_pop  genre|permanent_wave  genre|pop
# 0       0.848              0.699219   0.706055
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Similarity and Recommending

# %%
df2=df.copy()

# %%
playvec.iloc[0:1,18:]
# Out:
#   Artist_pop genre|permanent_wave genre|pop
# 0  42.400001             34.96875   35.3125

# %%
df['sim']=cosine_similarity(df.iloc[:,3:16],playvec.iloc[:,3:16])
df['sim2']=cosine_similarity(df.iloc[:,16:19],playvec.iloc[:,16:19])
df['sim3']=cosine_similarity(df.iloc[:,19:-4],playvec.iloc[:,19:])
df['sim4']= (df['sim']+df['sim2']+df['sim3'])/3
df = df.sort_values(['sim'],ascending = False,kind='stable')
qq=df.groupby('artist_uri').head(5).track_uri.head(50)     #to limit recmmendation by same artist
aa=sp.tracks(qq[0:50])
Fresult=pd.DataFrame()
for i in range(50):
    result=pd.DataFrame([i])
    result['track_name']=aa['tracks'][i]['name']
    result['artist_name']=aa['tracks'][i]['artists'][0]['name']
    #result['url']=aa['tracks'][i]['external_urls']['spotify']
    #result['image']=aa['tracks'][i]['album']['images'][1]['url']
    Fresult=pd.concat([Fresult,result],axis=0)
Fresult
# Out:
#     0                                    track_name  \
# 0   0                                       Gravity
# 0   1                                        Scream
# 0   2                      Dozen Roses & a Six-Pack
# 0   3                                     Hurricane
# 0   4     I Wish It Would Rain Down - 2016 Remaster
# 0   5                         Where You Are Tonight
# 0   6        Arrows (feat. Macklemore & Ryan Lewis)
# 0   7                                   White Trash
# 0   8                             Are You Happy Now
# 0   9                              I Still Miss You
# 0  10                                        Legacy
# 0  11                            Enamorada y Herida
# 0  12                                       Be Easy
# 0  13                                I'm a Disaster
# 0  14                               Dry County Girl
# 0  15                                       Warrior
# 0  16                                          Cake
# 0  17      Every Rose Has Its Thorn - 2003 Remaster
# 0  18                                   Sin Tu Amor
# 0  19                              The Boys of Fall
# 0  20                                       Thieves
# 0  21                            Beautiful Disaster
# 0  22                               We Don't Belong
# 0  23                              Daddy Had a Beer
# 0  24                                          不如這樣
# 0  25                                          Lucy
# 0  26                               Atado a Tu Amor
# 0  27                                       Grandpa
# 0  28                                   I Surrender
# 0  29                                   Used to You
# 0  30                                 Dear Prudence
# 0  31               That's What I Love About Sunday
# 0  32                        Heaven - 2005 Remaster
# 0  33                         Smashing The Opponent
# 0  34                                   Copper Wire
# 0  35                             Business as Usual
# 0  36                                   Te Esperaré
# 0  37                                      ¿Lo Ves?
# 0  38                                Wrapped in Red
# 0  39                                          悪ノ召使
# 0  40                                 Pieces of You
# 0  41                                I Want To Live
# 0  42                                          Home
# 0  43                                          Echo
# 0  44                               Noise Complaint
# 0  45                           Like My Mother Does
# 0  46                        Our Story - Radio Edit
# 0  47                                  Streetlights
# 0  48  Renew Me - Avalon 2004 Release Album Version
# 0  49                                     Deliverer
#
#                   artist_name
# 0  The Infamous Stringdusters
# 0                        Tank
# 0               Cole Swindell
# 0               Jimmy Needham
# 0                Phil Collins
# 0                   Kip Moore
# 0                      Fences
# 0                Chris Janson
# 0               Rascal Flatts
# 0                 Hawk Nelson
# 0            Nichole Nordeman
# 0                     Yuridia
# 0                 Alice Smith
# 0                  Ghost Town
# 0               Rascal Flatts
# 0             Yeah Yeah Yeahs
# 0            Melanie Martinez
# 0                      Poison
# 0                      Camila
# 0               Kenny Chesney
# 0                   She & Him
# 0              Jon McLaughlin
# 0                 Dash Berlin
# 0               Josh Thompson
# 0                  Eason Chan
# 0                     Skillet
# 0                    Chayanne
# 0                Justin Moore
# 0             Brandon Hampton
# 0                  Luke Combs
# 0              Dwight Twilley
# 0                Craig Morgan
# 0               Talking Heads
# 0           Infected Mushroom
# 0                   The Range
# 0                 Coma Cinema
# 0             Natalia Jiménez
# 0                 Sin Bandera
# 0              Kelly Clarkson
# 0                       mothy
# 0               Chris Carmack
# 0                 Josh Gracin
# 0            Kim Walker-Smith
# 0              Bad Meets Evil
# 0                      P.Keys
# 0               Lauren Alaina
# 0                        Mako
# 0                        Ludo
# 0                      Avalon
# 0                  Matt Maher

# %%
df['sim5']=df['sim']/df['sim'].max()

# %%
df['sim6']= (5*df['sim5']+3*df['sim2']+df['sim3'])/9

# %%
df = df.sort_values(['sim4'],ascending = False,kind='stable')
qq=df.groupby('artist_uri').head(5).track_uri.head(50)     #to limit recmmendation by same artist
aa=sp.tracks(qq[0:50])
Fresult=pd.DataFrame()
for i in range(50):
    result=pd.DataFrame([i])
    result['track_name']=aa['tracks'][i]['name']
    result['artist_name']=aa['tracks'][i]['artists'][0]['name']
    #result['url']=aa['tracks'][i]['external_urls']['spotify']
    #result['image']=aa['tracks'][i]['album']['images'][1]['url']
    Fresult=pd.concat([Fresult,result],axis=0)
Fresult
# Out:
#     0                                         track_name       artist_name
# 0   0                                       Viva La Vida          Coldplay
# 0   1                                A Sky Full of Stars          Coldplay
# 0   2                            Adventure of a Lifetime          Coldplay
# 0   3                                        Don't Panic          Coldplay
# 0   4                                   Christmas Lights          Coldplay
# 0   5                                        Desert Rose             Sting
# 0   6                                  Don't You Want Me  The Human League
# 0   7                                      Brand New Day             Sting
# 0   8                         Fortress Around Your Heart             Sting
# 0   9                              Practical Arrangement             Sting
# 0  10                                   A Thousand Years             Sting
# 0  11                    Love Action (I Believe In Love)  The Human League
# 0  12                                       Human - Edit  The Human League
# 0  13                                              Human  The Human League
# 0  14                                       Steppin' Out       Joe Jackson
# 0  15                         (Keep Feeling) Fascination  The Human League
# 0  16                                           My Girls   Tears For Fears
# 0  17                                       Got The Time       Joe Jackson
# 0  18                                        Look Sharp!       Joe Jackson
# 0  19                                      One More Time       Joe Jackson
# 0  20                                      Sunday Papers       Joe Jackson
# 0  21           Everybody Wants To Rule The World - Live   Tears For Fears
# 0  22                                       Shake It Off      Taylor Swift
# 0  23                                              Style      Taylor Swift
# 0  24                                        Blank Space      Taylor Swift
# 0  25                                     Wildest Dreams      Taylor Swift
# 0  26                                           Reminder        The Weeknd
# 0  27                                 Stargirl Interlude        The Weeknd
# 0  28                                   I Feel It Coming        The Weeknd
# 0  29                                      Party Monster        The Weeknd
# 0  30                                          Bad Blood      Taylor Swift
# 0  31                           Only Girl (In The World)           Rihanna
# 0  32                                                S&M           Rihanna
# 0  33                                Young And Beautiful      Lana Del Rey
# 0  34                                 Summertime Sadness      Lana Del Rey
# 0  35                                      Brooklyn Baby      Lana Del Rey
# 0  36                                 That's What I Like        Bruno Mars
# 0  37                               Just the Way You Are        Bruno Mars
# 0  38                                            Perfect        Ed Sheeran
# 0  39                                          Sidewalks        The Weeknd
# 0  40                                           Art Deco      Lana Del Rey
# 0  41                                Pretty When You Cry      Lana Del Rey
# 0  42  Moves Like Jagger - Studio Recording From "The...          Maroon 5
# 0  43                                Talking to the Moon        Bruno Mars
# 0  44                                               Maps          Maroon 5
# 0  45                                    Congratulations       Post Malone
# 0  46                                           Payphone          Maroon 5
# 0  47                 Hips Don't Lie (feat. Wyclef Jean)           Shakira
# 0  48                                          This Love          Maroon 5
# 0  49                                       Shape of You        Ed Sheeran

# %%
df.head()
# Out:
#                     track_uri              artist_uri               album_uri  \
# 91717  3wBzbRG2OnmKl9jYyR6umu  7yTltkMBvChBkA86Tz8WfW  0yXaxoA7bBeXc31NQxiv93
# 27507  67AiSvsRAPIt7JL1KDlvBq  4mwXUEKaW4ftbncf9Hi58l  3jliDnhfFupNVHNdOI4sKh
# 19185  3Ne1RRcRpIn2RBYyuidXcS  1mfDfLsMxYcOOZkzBxvSVW  2mlPEYhK1KwDD45CCCWxaH
# 59321  16LVMgMrnpCCgQyWMlXaMg  4yMGs8CtlMVF7RV2XU539m  50F9ClKFmuVCI1EU1aoEyK
# 19562  4F2t297QK40XFcIHqkmLHs  4lxfqrEsLX6N1N4OCSkILp  2sS9l8uc3d3UsK9unJyrD8
#
#        danceability  energy       key  loudness  mode  speechiness  \
# 91717      0.467611   0.613  0.636364  0.828459   1.0     0.028170
# 27507      0.637652   0.725  0.636364  0.857225   1.0     0.038981
# 19185      0.468623   0.723  0.727273  0.894781   1.0     0.030561
# 59321      0.536437   0.674  0.636364  0.866846   1.0     0.032952
# 19562      0.516194   0.667  0.727273  0.883514   1.0     0.030561
#
#        acousticness  ...  time_signature  Track_release_date  Track_pop  \
# 91717      0.213855  ...             0.8                 1.0   0.294118
# 27507      0.316265  ...             0.8                 1.0   0.235294
# 19185      0.252008  ...             0.8                 1.0   0.352941
# 59321      0.258032  ...             0.8                 1.0   0.176471
# 19562      0.293173  ...             0.8                 0.5   0.705882
#
#        Artist_pop  genre|permanent_wave  genre|pop       sim      sim2  sim3  \
# 91717        0.35                   0.0        0.0  0.988423  0.912232   0.0
# 27507        0.55                   0.0        0.0  0.988192  0.932686   0.0
# 19185        0.60                   0.0        0.0  0.987366  0.963074   0.0
# 59321        0.30                   0.0        0.0  0.987174  0.865514   0.0
# 19562        0.75                   0.0        0.0  0.986974  0.963867   0.0
#
#            sim4
# 91717  0.633552
# 27507  0.640293
# 19185  0.650147
# 59321  0.617563
# 19562  0.650280
#
# [5 rows x 25 columns]

# %%
df2['sim']=cosine_similarity(df2.iloc[:,3:16],playvec2.iloc[:,3:16])
df2['sim2']=cosine_similarity(df2.iloc[:,16:19],playvec2.iloc[:,16:19])
df2['sim3']=cosine_similarity(df2.iloc[:,19:-4],playvec2.iloc[:,19:])
df2['sim4']= (df2['sim']+df2['sim2']+df2['sim3'])/3
df2 = df2.sort_values(['sim'],ascending = False,kind='stable')
qq=df2.groupby('artist_uri').head(5).track_uri.head(50)     #to limit recmmendation by same artist
aa=sp.tracks(qq[0:50])
Fresult2=pd.DataFrame()
for i in range(50):
    result=pd.DataFrame([i])
    result['track_name']=aa['tracks'][i]['name']
    result['artist_name']=aa['tracks'][i]['artists'][0]['name']
    #result['url']=aa['tracks'][i]['external_urls']['spotify']
    #result['image']=aa['tracks'][i]['album']['images'][1]['url']
    Fresult2=pd.concat([Fresult2,result],axis=0)
Fresult2
# Out:
#     0                                         track_name  \
# 0   0                              Interlude: Talk Radio
# 0   1                                           Overture
# 0   2  Dungeons and Dragons Theme (Instrumental Version)
# 0   3                                   The Cube - Scene
# 0   4                                         The Letter
# 0   5                            The Westward Procession
# 0   6                      Doctor Who Theme - TV Version
# 0   7                             Stay Alive - Interlude
# 0   8                        All Blues - Studio Sequence
# 0   9                                       Electric Zoo
# 0  10                              Malatikalano Polatina
# 0  11                                      Mia Gets Home
# 0  12                                   (Drill Sergeant)
# 0  13                             The Walking Dead Theme
# 0  14                        Happy Holidays, You Bastard
# 0  15                                     Happy Holidays
# 0  16  Finale (Peace on Earth) - From "Lady and the T...
# 0  17  Elephant Parade - From "Eternal Sunshine of th...
# 0  18                               Five Little Pumpkins
# 0  19                     Interlude: The Glory is in You
# 0  20                                 Preschool Popstars
# 0  21                                    Uncle Buford #1
# 0  22                               The Sound Of Silence
# 0  23                     Intro: I Switched My Robot Off
# 0  24  Jesu Joy of Man's Desiring Relaxing Classical ...
# 0  25                                 DJ Black interlude
# 0  26  Gravity Falls Main Title Theme (from "Gravity ...
# 0  27                               Look Alive, Sunshine
# 0  28                              Narrative Call - Skit
# 0  29                                          The Knife
# 0  30  Interlude: I Got So Much Magic, You Can Have I...
# 0  31                           The Cow as White as Milk
# 0  32           ...P. Sherman, 42 Wallaby Way, Sydney...
# 0  33                                 DJ Black Interlude
# 0  34        Christmas Seals Public Service Announcement
# 0  35                                     Backyard Beach
# 0  36                                          Interlude
# 0  37                                       WDPK 83.7 FM
# 0  38                 Interlude: The Non-Conformist Oath
# 0  39                                      Frank's Track
# 0  40                                    Uncle Buford #2
# 0  41                                 Sorry, Dad - Score
# 0  42                                       Empty Spaces
# 0  43                                              Lions
# 0  44                   Public Service Announcement 2000
# 0  45        Jet-Star and the Kobra Kid / Traffic Report
# 0  46                               Welcome to Gusteau's
# 0  47                                    The Walking Out
# 0  48                             Fuck This Shit I'm Out
# 0  49  I Have A Hole In My Tooth (And My Dentist is S...
#
#              artist_name
# 0               Gorillaz
# 0          Icon For Hire
# 0      Cult Hit Tributes
# 0                  Logic
# 0                Outkast
# 0       Hillsong Worship
# 0            Murray Gold
# 0               J.PERIOD
# 0            Miles Davis
# 0  Spongebob Squarepants
# 0            The Minions
# 0         Justin Hurwitz
# 0                   Muse
# 0           Retrospectre
# 0              blink-182
# 0              blink-182
# 0   Disney Studio Chorus
# 0              Jon Brion
# 0                  Raffi
# 0                Solange
# 0     Preschool Popstars
# 0    Da Vinci's Notebook
# 0          Anna Kendrick
# 0               Gorillaz
# 0       Isabella Jenkins
# 0          Three 6 Mafia
# 0            Brad Breeck
# 0    My Chemical Romance
# 0                Ashanti
# 0       Bernard Herrmann
# 0                Solange
# 0            Emily Blunt
# 0          Thomas Newman
# 0          Three 6 Mafia
# 0          Frank Sinatra
# 0                   Ferb
# 0          Three 6 Mafia
# 0              Daft Punk
# 0               Gorillaz
# 0             Kanye West
# 0    Da Vinci's Notebook
# 0            John Debney
# 0            Linkin Park
# 0          WALK THE MOON
# 0                 Eminem
# 0    My Chemical Romance
# 0      Michael Giacchino
# 0       Josh Abbott Band
# 0         The Theme Song
# 0                  dodie

# %%
df2.iloc[0:1,16:19]
# Out:
#       Track_release_date  Track_pop  Artist_pop
# 3409                  40          1          15

# %%
playvec2.iloc[:,16:19]
# Out:
#    Track_release_date  Track_pop  Artist_pop
# 0                 1.0   0.593529       0.417

# %%
playvec.iloc[:,16:19]
# Out:
#   Track_release_date  Track_pop Artist_pop
# 0              100.0  59.352943  41.700001

# %%
cosine_similarity(df2.iloc[0:1,16:19],playvec.iloc[:,16:19])
# Out:
# array([[0.88745157]])

# %%
Fresult.head()
# Out:
#    0                                         track_name        artist_name
# 0  0                              Interlude: Talk Radio           Gorillaz
# 0  1                                           Overture      Icon For Hire
# 0  2  Dungeons and Dragons Theme (Instrumental Version)  Cult Hit Tributes
# 0  3                                   The Cube - Scene              Logic
# 0  4                                         The Letter            Outkast

# %%
df.head()
# Out:
#                     track_uri              artist_uri               album_uri  \
# 3409   5f0FCcrkvyhiRT5wynS0XN  3AA28KZvwAUcZuOKwyblJQ  0NvirtaDCaZU5PAW1O5FDE
# 49930  5SVWMBJhwrBDYLioEOmDBw  1Jy0lTKAQDnTklKzF0g2o7  034rIpQ6gBG6lASW3nnuNT
# 97634  1jNb6NlxXc6BmFMEHMIyEM  5jAQe0gOlmlyNKyfd5d2jH  6OT1X94BRhcaDj5CKswYCX
# 10822  30S46V7RcyGXUModoqW69b  4xRYI6VqpkE3UwrDrAZL8L  5dOpbgAmJeyoakKQ0QLWkR
# 532    0RBlLGGoMx0AxCsO4XyjGa  1G9G7WwrXka3Z1r7aIDjI7  1UsmQ3bpJTyK6ygoOOjG1r
#
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 3409          0.263   0.935   0.0    -7.934   1.0       0.1430       0.77800
# 49930         0.207   0.658  11.0    -8.450   1.0       0.0636       0.03960
# 97634         0.296   0.707   8.0    -8.300   1.0       0.0421       0.00231
# 10822         0.453   0.245   1.0   -21.580   1.0       0.3020       0.11700
# 532           0.697   0.110   0.0   -23.550   1.0       0.9170       0.16700
#
#        ...  Track_release_date  Track_pop  Artist_pop  genre|fi_jazzhop  \
# 3409   ...                  40          1          15               0.0
# 49930  ...                  40          1          10               0.0
# 97634  ...                  40          1           5               0.0
# 10822  ...                  40          1          14               0.0
# 532    ...                  40          1          14               0.0
#
#        genre|lo       sim      sim2  sim3      sim4      sim5
# 3409        0.0  0.014329  0.887452   0.0  0.300594  1.000000
# 49930       0.0  0.014000  0.878560   0.0  0.297520  0.977037
# 97634       0.0  0.013978  0.856738   0.0  0.290239  0.975512
# 10822       0.0  0.013896  0.886621   0.0  0.300172  0.969753
# 532         0.0  0.013879  0.886621   0.0  0.300167  0.968594
#
# [5 rows x 26 columns]

# %%
df2.head()
# Out:
#                     track_uri              artist_uri               album_uri  \
# 3409   5f0FCcrkvyhiRT5wynS0XN  3AA28KZvwAUcZuOKwyblJQ  0NvirtaDCaZU5PAW1O5FDE
# 49930  5SVWMBJhwrBDYLioEOmDBw  1Jy0lTKAQDnTklKzF0g2o7  034rIpQ6gBG6lASW3nnuNT
# 97634  1jNb6NlxXc6BmFMEHMIyEM  5jAQe0gOlmlyNKyfd5d2jH  6OT1X94BRhcaDj5CKswYCX
# 10822  30S46V7RcyGXUModoqW69b  4xRYI6VqpkE3UwrDrAZL8L  5dOpbgAmJeyoakKQ0QLWkR
# 532    0RBlLGGoMx0AxCsO4XyjGa  1G9G7WwrXka3Z1r7aIDjI7  1UsmQ3bpJTyK6ygoOOjG1r
#
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 3409          0.263   0.935   0.0    -7.934   1.0       0.1430       0.77800
# 49930         0.207   0.658  11.0    -8.450   1.0       0.0636       0.03960
# 97634         0.296   0.707   8.0    -8.300   1.0       0.0421       0.00231
# 10822         0.453   0.245   1.0   -21.580   1.0       0.3020       0.11700
# 532           0.697   0.110   0.0   -23.550   1.0       0.9170       0.16700
#
#        ...  time_signature  Track_release_date  Track_pop  Artist_pop  \
# 3409   ...             3.0                  40          1          15
# 49930  ...             4.0                  40          1          10
# 97634  ...             4.0                  40          1           5
# 10822  ...             1.0                  40          1          14
# 532    ...             5.0                  40          1          14
#
#        genre|fi_jazzhop  genre|lo       sim      sim2  sim3      sim4
# 3409                0.0       0.0  0.014329  0.887452   0.0  0.300594
# 49930               0.0       0.0  0.014000  0.878560   0.0  0.297520
# 97634               0.0       0.0  0.013978  0.856738   0.0  0.290239
# 10822               0.0       0.0  0.013896  0.886621   0.0  0.300172
# 532                 0.0       0.0  0.013879  0.886621   0.0  0.300167
#
# [5 rows x 25 columns]

# %%
Fresult2.head()
# Out:
#    0                                         track_name        artist_name
# 0  0                              Interlude: Talk Radio           Gorillaz
# 0  1                                           Overture      Icon For Hire
# 0  2  Dungeons and Dragons Theme (Instrumental Version)  Cult Hit Tributes
# 0  3                                   The Cube - Scene              Logic
# 0  4                                         The Letter            Outkast

# %%
df['sim']=cosine_similarity(df.iloc[:,3:16],playvec.iloc[:,3:16])
df['sim2']=cosine_similarity(df.loc[:, df.columns.str.startswith('T')|df.columns.str.startswith('A')],playvec.loc[:, playvec.columns.str.startswith('T')|playvec.columns.str.startswith('A')])
df['sim3']=cosine_similarity(df.loc[:, df.columns.str.startswith('genre')],playvec.loc[:, playvec.columns.str.startswith('genre')])
df['sim4']=(df['sim']+df['sim2']+df['sim3'])/3
df = df.sort_values(['sim4'],ascending = False,kind='stable')
# genra>audio>pop
qq=df.groupby('artist_uri').head(5).track_uri.head(50)
aa=sp.tracks(qq[0:50])
Fresult=pd.DataFrame()
for i in range(50):
    result=pd.DataFrame([i])
    result['track_name']=aa['tracks'][i]['name']
    result['artist_name']=aa['tracks'][i]['artists'][0]['name']
    #result['url']=aa['tracks'][i]['external_urls']['spotify']
    #result['image']=aa['tracks'][i]['album']['images'][1]['url']
    Fresult=pd.concat([Fresult,result],axis=0)
Fresult
# Out:
#     0                                         track_name        artist_name
# 0   0                            Adventure of a Lifetime           Coldplay
# 0   1                                        In My Place           Coldplay
# 0   2                                   Christmas Lights           Coldplay
# 0   3                                             Shiver           Coldplay
# 0   4                     God Put a Smile upon Your Face           Coldplay
# 0   5                                  Don't You Want Me   The Human League
# 0   6                                       Steppin' Out        Joe Jackson
# 0   7                                              Human   The Human League
# 0   8                                       Human - Edit   The Human League
# 0   9                                      Brand New Day              Sting
# 0  10                         Fortress Around Your Heart              Sting
# 0  11                    Love Action (I Believe In Love)   The Human League
# 0  12                                        Desert Rose              Sting
# 0  13                                 Breaking Us In Two        Joe Jackson
# 0  14                                   A Thousand Years              Sting
# 0  15                              Practical Arrangement              Sting
# 0  16                                       Got The Time        Joe Jackson
# 0  17                                      Sunday Papers        Joe Jackson
# 0  18                                        Look Sharp!        Joe Jackson
# 0  19                       Fascination - Extended Remix   The Human League
# 0  20                                    Sweater Weather  The Neighbourhood
# 0  21                    All I Want for Christmas Is You       Mariah Carey
# 0  22                                       Heart Attack        Demi Lovato
# 0  23                               Just the Way You Are         Bruno Mars
# 0  24                                  Sign of the Times       Harry Styles
# 0  25                                    Congratulations        Post Malone
# 0  26                                            Perfect         Ed Sheeran
# 0  27                                      Bleeding Love        Leona Lewis
# 0  28                                 How to Save a Life           The Fray
# 0  29                                            Believe               Cher
# 0  30                                          Right Now      One Direction
# 0  31                                            Silence         Marshmello
# 0  32                                         The Nights             Avicii
# 0  33                                        Unstoppable                Sia
# 0  34                                      Call Me Maybe   Carly Rae Jepsen
# 0  35                                               Ride  Twenty One Pilots
# 0  36                                           Reminder         The Weeknd
# 0  37                                      White Iverson        Post Malone
# 0  38                                               Team              Lorde
# 0  39  Love Me Like You Do - From "Fifty Shades Of Grey"     Ellie Goulding
# 0  40                             Sugar, We're Goin Down       Fall Out Boy
# 0  41                                             Closer   The Chainsmokers
# 0  42                                      Broken Clocks                SZA
# 0  43                                       Daddy Issues  The Neighbourhood
# 0  44                                            Riptide          Vance Joy
# 0  45        Feel This Moment (feat. Christina Aguilera)            Pitbull
# 0  46                                           Payphone           Maroon 5
# 0  47                                   a thousand years    Christina Perri
# 0  48                                         PILLOWTALK               ZAYN
# 0  49                                           Maneater      Nelly Furtado

# %%
Spotifyresult=pd.DataFrame()
for i in range(len(test)-1):
    if len(Spotifyresult)>=50:
        break
    ff=sp.recommendations(seed_tracks=list(test.track_uri[1+i:5+i]),limit=2)
    for z in range(2):
        result=pd.DataFrame([z+(2*i)+1])
        result['track_name']=ff['tracks'][z]['name']
        result['artist_name']=ff['tracks'][z]['artists'][0]['name']
        #result['uri']=ff['tracks'][z]['id']
        #result['url']=ff['tracks'][z]['external_urls']['spotify']
        #result['image']=ff['tracks'][z]['album']['images'][1]['url']
        Spotifyresult=pd.concat([Spotifyresult,result],axis=0)
Spotifyresult
# Out:
#     0                                         track_name  \
# 0   1                                              Jaded
# 0   2                                Stay on These Roads
# 0   3                 See You Again (feat. Charlie Puth)
# 0   4                                             Empire
# 0   5                      Love Not War (The Tampa Beat)
# 0   6                                     Sweet Creature
# 0   7                                  Still Fighting It
# 0   8                                    A Lack of Color
# 0   9                                Burning the heather
# 0  10                                   Among The Living
# 0  11      Overtura - Music Of The Spheres album trailer
# 0  12                                       I'm with You
# 0  13                                     Bigger Than Us
# 0  14                                          Syndicate
# 0  15                                  Hurts Like Heaven
# 0  16                                Gold on the Ceiling
# 0  17                                         Those Eyes
# 0  18                                  Hey There Delilah
# 0  19                                               Talk
# 0  20                                            7 Years
# 0  21                                       Yellow Light
# 0  22                                          24K Magic
# 0  23                   When You Love Someone - Acoustic
# 0  24                               she's all i wanna be
# 0  25                                            Nothing
# 0  26                                             Yellow
# 0  27                                           Stitches
# 0  28                                             Helium
# 0  29                                         Chandelier
# 0  30  Rocket Man (I Think It's Going To Be A Long, L...
# 0  31                                        Violet Hill
# 0  32                                            You & I
# 0  33                                               Mama
# 0  34                                         Good Grief
# 0  35                                           Miracles
# 0  36                                          Good Time
# 0  37                                    Love Dies Young
# 0  38                                             Cherry
# 0  39                  Good Riddance (Time of Your Life)
# 0  40                                   I Feel It Coming
# 0  41                                      jar of hearts
# 0  42                                           The Cave
# 0  43                                        Imagination
# 0  44                                            Riptide
# 0  45                                       Mess Is Mine
# 0  46                           Street Spirit (Fade Out)
# 0  47                                              Lost!
# 0  48                               Washing Of The Water
# 0  49                                   Dark Necessities
# 0  50                                   For Me, It's You
#
#              artist_name
# 0              Aerosmith
# 0                   a-ha
# 0            Wiz Khalifa
# 0    Of Monsters and Men
# 0           Jason Derulo
# 0           Harry Styles
# 0              Ben Folds
# 0    Death Cab for Cutie
# 0          Pet Shop Boys
# 0             The Thorns
# 0               Coldplay
# 0              Vance Joy
# 0             White Lies
# 0               The Fray
# 0               Coldplay
# 0         The Black Keys
# 0               New West
# 0        Plain White T's
# 0               Coldplay
# 0           Lukas Graham
# 0    Of Monsters and Men
# 0             Bruno Mars
# 0               James TW
# 0             Tate McRae
# 0             The Script
# 0               Coldplay
# 0           Shawn Mendes
# 0                    Sia
# 0                    Sia
# 0             Elton John
# 0               Coldplay
# 0          One Direction
# 0             Jonas Blue
# 0               Bastille
# 0               Coldplay
# 0               Owl City
# 0           Foo Fighters
# 0           Harry Styles
# 0              Green Day
# 0             The Weeknd
# 0        Christina Perri
# 0         Mumford & Sons
# 0           Shawn Mendes
# 0              Vance Joy
# 0              Vance Joy
# 0              Radiohead
# 0               Coldplay
# 0          Peter Gabriel
# 0  Red Hot Chili Peppers
# 0                Lo Moon

# %%
df.iloc[0:1,3:16]
# Out:
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 113344         0.486   0.617  5.0    -7.113   0.0       0.0287        0.0954
#
#         instrumentalness  liveness  valence  tempo  duration_ms  \
# 113344          0.000003     0.109    0.417  138.0     242373.0
#
#         time_signature
# 113344             4.0

# %%
cosine_similarity(df.iloc[0:1,3:16],playvec.iloc[0:1,3:16])
# Out:
# array([[0.02831392]])

# %% [markdown]
# ## Resaving scaler after modifying dataset

# %%
import pandas as pd
import pickle

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
dtypes = {'track_uri': 'object', 'artist_uri': 'object', 'album_uri': 'object', 'danceability': 'float16', 'energy': 'float16', 'key': 'float16',
'loudness': 'float16', 'mode': 'float16', 'speechiness': 'float16', 'acousticness': 'float16', 'instrumentalness': 'float16',
'liveness': 'float16', 'valence': 'float16', 'tempo': 'float16', 'duration_ms': 'float32', 'time_signature': 'float16',
'Track_release_date': 'int8', 'Track_pop': 'int8', 'Artist_pop': 'int8', 'Artist_genres': 'object'}
col_name= ['track_uri', 'artist_uri', 'album_uri', 'danceability', 'energy', 'key',
'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
'Track_release_date', 'Track_pop', 'Artist_pop', 'Artist_genres']

# %%
df=pd.read_csv("Streamlit/data/streamlit_data.csv",dtype=dtypes,names=col_name,skiprows=1)

# %%
df.iloc[0]
# Out:
# track_uri                                        0UaMYEvWZi0ZqiDOoHU3YI
# artist_uri                                       2wIVse2owClT7go1WT98tk
# album_uri                                        6vV5UrXcfyQD1wu4Qo2I9K
# danceability                                                   0.903809
# energy                                                         0.812988
# key                                                                 4.0
# loudness                                                      -7.105469
# mode                                                                0.0
# speechiness                                                    0.120972
# acousticness                                                   0.031097
# instrumentalness                                               0.006969
# liveness                                                       0.047089
# valence                                                        0.810059
# tempo                                                          125.4375
# duration_ms                                                    226864.0
# time_signature                                                      4.0
# Track_release_date                                                   40
# Track_pop                                                            14
# Artist_pop                                                           14
# Artist_genres         dance_pop hip_hop hip_pop neo_soul pop_rap r&b...
# Name: 0.0, dtype: object

# %%
index=0
for x in df.columns:
    print(f"{index} - {x}")
    index+=1
# Out:
# 0 - track_uri
# 1 - artist_uri
# 2 - album_uri
# 3 - danceability
# 4 - energy
# 5 - key
# 6 - loudness
# 7 - mode
# 8 - speechiness
# 9 - acousticness
# 10 - instrumentalness
# 11 - liveness
# 12 - valence
# 13 - tempo
# 14 - duration_ms
# 15 - time_signature
# 16 - Track_release_date
# 17 - Track_pop
# 18 - Artist_pop
# 19 - Artist_genres

# %%
df.iloc[:,3:19].min()
# Out:
# danceability             0.0
# energy                   0.0
# key                      0.0
# loudness               -60.0
# mode                     0.0
# speechiness              0.0
# acousticness             0.0
# instrumentalness         0.0
# liveness                 0.0
# valence                  0.0
# tempo                    0.0
# duration_ms           4853.0
# time_signature           0.0
# Track_release_date      38.0
# Track_pop                1.0
# Artist_pop               0.0
# dtype: float32

# %%
sc=MinMaxScaler()
df.iloc[:,3:19]=sc.fit_transform(df.iloc[:,3:19])
pickle.dump(sc, open('data/sc.sav', 'wb'))

# %%
df.iloc[0]
# Out:
# track_uri                                        0UaMYEvWZi0ZqiDOoHU3YI
# artist_uri                                       2wIVse2owClT7go1WT98tk
# album_uri                                        6vV5UrXcfyQD1wu4Qo2I9K
# danceability                                                   0.914978
# energy                                                         0.812988
# key                                                            0.363636
# loudness                                                       0.845309
# mode                                                                0.0
# speechiness                                                    0.125761
# acousticness                                                   0.031219
# instrumentalness                                               0.006983
# liveness                                                       0.047089
# valence                                                        0.810059
# tempo                                                          0.529831
# duration_ms                                                    0.042088
# time_signature                                                      0.8
# Track_release_date                                                  1.0
# Track_pop                                                      0.764706
# Artist_pop                                                          0.7
# Artist_genres         dance_pop hip_hop hip_pop neo_soul pop_rap r&b...
# Name: 0, dtype: object

# %% [markdown]
# ## Cosine Similarity between audio features

# %%
tracks=sp.audio_features(["1mea3bSkSGXuIRvnydlB5b"])

# %%
audio_features=pd.DataFrame(tracks)

# %%
audio_features.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature'],
#       dtype='object')

# %%
sc = pickle.load(open('Streamlit/data/sc.sav','rb'))

# %%
audio_feat_dropped=audio_features.drop([ 'type', 'id','track_href', 'analysis_url'],axis=1)

# %%
audio_feat_dropped["Track_release_date"]=0
audio_feat_dropped["Artist_pop"]=0
audio_feat_dropped["Track_pop"]=0
audio_feat_dropped.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'uri', 'duration_ms', 'time_signature', 'Track_release_date',
#        'Artist_pop', 'Track_pop'],
#       dtype='object')

# %%
audio_feat_dropped=audio_feat_dropped[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_ms', 'time_signature','Track_release_date','Track_pop', 'Artist_pop',
        'uri']]

# %%
audio_feat_dropped.iloc[:,:-1]=sc.transform(audio_feat_dropped.iloc[:,:-1])

# %%
audio_feat_dropped
# Out:
#    danceability  energy       key  loudness  mode  speechiness  acousticness  \
# 0      0.491903   0.617  0.454545  0.845159   0.0     0.029834      0.095783
#
#    instrumentalness  liveness  valence     tempo  duration_ms  time_signature  \
# 0          0.000003     0.109    0.417  0.582834     0.045028             0.8
#
#    Track_release_date  Track_pop  Artist_pop  \
# 0               -19.0  -0.058824         0.0
#
#                                     uri
# 0  spotify:track:1mea3bSkSGXuIRvnydlB5b

# %%
audio_feat_dropped.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'time_signature', 'Track_release_date', 'Track_pop',
#        'Artist_pop', 'uri'],
#       dtype='object')

# %%
audio_feat_dropped=audio_feat_dropped[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
       'uri']]

# %%
audio_feat_dropped.iloc[0:1,:-1]
# Out:
#    danceability  energy       key  loudness  mode  speechiness  acousticness  \
# 0      0.491903   0.617  0.454545  0.845159   0.0     0.029834      0.095783
#
#    instrumentalness  liveness  valence     tempo  duration_ms  time_signature
# 0          0.000003     0.109    0.417  0.582834     0.045028             0.8

# %%
df.iloc[0:1,3:16]
# Out:
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 113344         0.486   0.617  5.0    -7.113   0.0       0.0287        0.0954
#
#         instrumentalness  liveness  valence  tempo  duration_ms  \
# 113344          0.000003     0.109    0.417  138.0     242373.0
#
#         time_signature
# 113344             4.0

# %%
cosine_similarity(audio_feat_dropped.iloc[0:1,:-1],playvec.iloc[0:1,3:16])
# Out:
# array([[0.90171789]])

# %%
cosine_similarity(df.iloc[0:1,3:16],playvec.iloc[0:1,3:16])
# Out:
# array([[0.02831392]])
