# %%
import pandas as pd

# %% [markdown]
# ## Replaced Rows

# %%
df_my=pd.read_csv("./Streamlit/data/final_streamlit_modeldata.csv")

# %%
df_downloaded=pd.read_csv("streamlit.csv")

# %%
df_my.columns
# Out:
# Index(['track_uri', 'artist_uri', 'album_uri', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
#        'Artist_genres', 'Track_pop', 'Artist_pop', 'Track_release_date'],
#       dtype='object')

# %%
df_downloaded.columns
# Out:
# Index(['track_uri', 'artist_uri', 'album_uri', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
#        'Track_release_date', 'Track_pop', 'Artist_pop', 'Artist_genres'],
#       dtype='object')

# %%
df_my.head()
# Out:
#                 track_uri              artist_uri               album_uri  \
# 0  0UaMYEvWZi0ZqiDOoHU3YI  2wIVse2owClT7go1WT98tk  6vV5UrXcfyQD1wu4Qo2I9K
# 1  3jagJCUbdqhDSPuxP8cAqF  2wIVse2owClT7go1WT98tk  6DeU398qrJ1bLuryetSmup
# 2  3XplJgPz8VjbDzbGwGgZdq  2wIVse2owClT7go1WT98tk  6epR3D622KWsnuHye7ApOl
# 3  0jG92AlXau21qgCQRxGLic  2wIVse2owClT7go1WT98tk  20t54K6C80QQH7vbcpfJcP
# 4  6zsk6uF3MxfIeHPlubKBvR  2wIVse2owClT7go1WT98tk  20t54K6C80QQH7vbcpfJcP
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.904   0.813  4.0    -7.105   0.0        0.121        0.0311
# 1         0.884   0.677  1.0    -5.600   1.0        0.283        0.0778
# 2         0.794   0.805  0.0    -6.555   1.0        0.230        0.5380
# 3         0.622   0.669  9.0    -8.420   1.0        0.329        0.0266
# 4         0.797   0.750  0.0    -9.370   1.0        0.247        0.5330
#
#    instrumentalness  liveness  valence   tempo  duration_ms  time_signature  \
# 0          0.006970    0.0471    0.810  125.44     226864.0             4.0
# 1          0.000000    0.0732    0.584  101.90     263227.0             4.0
# 2          0.122000    0.0952    0.658  177.80     236933.0             4.0
# 3          0.000003    0.1520    0.570   93.80     252987.0             4.0
# 4          0.108000    0.0950    0.740  177.90     211120.0             4.0
#
#                                        Artist_genres  Track_pop  Artist_pop  \
# 0  dance_pop hip_hop hip_pop neo_soul pop_rap r&b...         14          14
# 1  dance_pop hip_hop hip_pop neo_soul pop_rap r&b...         14          14
# 2  dance_pop hip_hop hip_pop neo_soul pop_rap r&b...          8          14
# 3  dance_pop hip_hop hip_pop neo_soul pop_rap r&b...         11          14
# 4  dance_pop hip_hop hip_pop neo_soul pop_rap r&b...         14          14
#
#    Track_release_date
# 0                  40
# 1                  40
# 2                  40
# 3                  40
# 4                  40

# %%
df_my=df_my[['track_uri', 'artist_uri', 'album_uri', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
       'Track_release_date', 'Track_pop', 'Artist_pop', 'Artist_genres']]

# %%
df_my.head()
# Out:
#                 track_uri              artist_uri               album_uri  \
# 0  0UaMYEvWZi0ZqiDOoHU3YI  2wIVse2owClT7go1WT98tk  6vV5UrXcfyQD1wu4Qo2I9K
# 1  3jagJCUbdqhDSPuxP8cAqF  2wIVse2owClT7go1WT98tk  6DeU398qrJ1bLuryetSmup
# 2  3XplJgPz8VjbDzbGwGgZdq  2wIVse2owClT7go1WT98tk  6epR3D622KWsnuHye7ApOl
# 3  0jG92AlXau21qgCQRxGLic  2wIVse2owClT7go1WT98tk  20t54K6C80QQH7vbcpfJcP
# 4  6zsk6uF3MxfIeHPlubKBvR  2wIVse2owClT7go1WT98tk  20t54K6C80QQH7vbcpfJcP
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.904   0.813  4.0    -7.105   0.0        0.121        0.0311
# 1         0.884   0.677  1.0    -5.600   1.0        0.283        0.0778
# 2         0.794   0.805  0.0    -6.555   1.0        0.230        0.5380
# 3         0.622   0.669  9.0    -8.420   1.0        0.329        0.0266
# 4         0.797   0.750  0.0    -9.370   1.0        0.247        0.5330
#
#    instrumentalness  liveness  valence   tempo  duration_ms  time_signature  \
# 0          0.006970    0.0471    0.810  125.44     226864.0             4.0
# 1          0.000000    0.0732    0.584  101.90     263227.0             4.0
# 2          0.122000    0.0952    0.658  177.80     236933.0             4.0
# 3          0.000003    0.1520    0.570   93.80     252987.0             4.0
# 4          0.108000    0.0950    0.740  177.90     211120.0             4.0
#
#    Track_release_date  Track_pop  Artist_pop  \
# 0                  40         14          14
# 1                  40         14          14
# 2                  40          8          14
# 3                  40         11          14
# 4                  40         14          14
#
#                                        Artist_genres
# 0  dance_pop hip_hop hip_pop neo_soul pop_rap r&b...
# 1  dance_pop hip_hop hip_pop neo_soul pop_rap r&b...
# 2  dance_pop hip_hop hip_pop neo_soul pop_rap r&b...
# 3  dance_pop hip_hop hip_pop neo_soul pop_rap r&b...
# 4  dance_pop hip_hop hip_pop neo_soul pop_rap r&b...

# %%
df_my.to_csv("./Streamlit/data/streamlit_data.csv")
df_my.to_parquet("./Streamlit/data/streamlit_data.parquet")

# %%
dtypes = {'track_uri': 'object', 'artist_uri': 'object', 'album_uri': 'object', 'danceability': 'float16', 'energy': 'float16', 'key': 'float16',
'loudness': 'float16', 'mode': 'float16', 'speechiness': 'float16', 'acousticness': 'float16', 'instrumentalness': 'float16',
'liveness': 'float16', 'valence': 'float16', 'tempo': 'float16', 'duration_ms': 'float32', 'time_signature': 'float16',
'Track_release_date': 'int8', 'Track_pop': 'int8', 'Artist_pop': 'int8', 'Artist_genres': 'object'}
col_name= ['track_uri', 'artist_uri', 'album_uri', 'danceability', 'energy', 'key',
'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
'Track_release_date', 'Track_pop', 'Artist_pop', 'Artist_genres']

# %%
df = pd.read_csv("./Streamlit/data/streamlit_data.csv",dtype=dtypes,names=col_name,skiprows=1)

# %%
df.drop(['track_uri', 'artist_uri', 'album_uri'], axis = 1).dtypes
# Out:
# danceability          float16
# energy                float16
# key                   float16
# loudness              float16
# mode                  float16
# speechiness           float16
# acousticness          float16
# instrumentalness      float16
# liveness              float16
# valence               float16
# tempo                 float16
# duration_ms           float32
# time_signature        float16
# Track_release_date       int8
# Track_pop                int8
# Artist_pop               int8
# Artist_genres          object
# dtype: object

# %% [markdown]
# ## Checked Playlist Model

# %%
import pandas as pd
import numpy as np

import spotipy
from spotipy.oauth2 import SpotifyOAuth,SpotifyClientCredentials
import yaml

# %%
import re

# %%
stream= open("spotify/spotify.yaml")
spotify_details = yaml.safe_load(stream)
auth_manager = SpotifyClientCredentials(client_id=spotify_details['Client_id'],
                                        client_secret=spotify_details['client_secret'])
sp = spotipy.client.Spotify(auth_manager=auth_manager)

# %%
dtypes = {'track_uri': 'object', 'artist_uri': 'object', 'album_uri': 'object', 'danceability': 'float16', 'energy': 'float16', 'key': 'float16',
'loudness': 'float16', 'mode': 'float16', 'speechiness': 'float16', 'acousticness': 'float16', 'instrumentalness': 'float16',
'liveness': 'float16', 'valence': 'float16', 'tempo': 'float16', 'duration_ms': 'float32', 'time_signature': 'float16',
'Track_release_date': 'int8', 'Track_pop': 'int8', 'Artist_pop': 'int8', 'Artist_genres': 'object'}
col_name= ['track_uri', 'artist_uri', 'album_uri', 'danceability', 'energy', 'key',
'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
'Track_release_date', 'Track_pop', 'Artist_pop', 'Artist_genres']

# %%
def get_IDs(user, playlist_id):
    # log.append('start playlist extraction')
    track_ids = []
    artist_id = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        track_ids.append(track['id'])
        artist = item['track']['artists']
        artist_id.append(artist[0]['id'])
    return track_ids, artist_id

# %%
track_ids, artist_id = get_IDs('316yiwiyxgcdn5m5eurpnlc4dcda', "37i9dQZF1DX3Kdv0IChEm9")

# %%
artist_id_uni = list(set(artist_id))
track_ids_uni = list(set(track_ids))

# %%
def extract(track_ids_uni, artist_id_uni):
    err = []
    err.append('Start audio features extraction')
    audio_features = pd.DataFrame()
    for i in range(0, len(track_ids_uni), 25):
        try:
            track_feature = sp.audio_features(track_ids_uni[i:i+25])
            track_df = pd.DataFrame(track_feature)
            audio_features = pd.concat([audio_features, track_df], axis=0)
        except Exception as e:
            err.append(e)
            continue
    err.append('Start track features extraction')
    track_ = pd.DataFrame()
    for i in range(0, len(track_ids_uni), 25):
        try:
            track_features = sp.tracks(track_ids_uni[i:i+25])
            for x in range(len(track_features['tracks'])):
                track_pop = pd.DataFrame([track_ids_uni[i+x]], columns=['Track_uri'])
                track_pop['Track_release_date'] = track_features['tracks'][x]['album']['release_date']
                track_pop['Track_pop'] = track_features['tracks'][x]["popularity"]
                track_pop['Artist_uri'] = track_features['tracks'][x]['artists'][0]['id']
                track_pop['Album_uri'] = track_features['tracks'][x]['album']['id']
                track_ = pd.concat([track_, track_pop], axis=0)
        except Exception as e:
            err.append(e)
            continue
    err.append('Start artist features extraction')
    artist_ = pd.DataFrame()
    for i in range(0, len(artist_id_uni), 25):
        try:
            artist_features = sp.artists(artist_id_uni[i:i+25])
            for x in range(len(artist_features['artists'])):
                artist_df = pd.DataFrame([artist_id_uni[i+x]], columns=['Artist_uri'])
                artist_pop = artist_features['artists'][x]["popularity"]
                artist_genres = artist_features['artists'][x]["genres"]
                artist_df["Artist_pop"] = artist_pop
                if artist_genres:
                    artist_df["genres"] = " ".join([re.sub(' ', '_', i) for i in artist_genres])
                else:
                    artist_df["genres"] = "unknown"
                artist_ = pd.concat([artist_, artist_df], axis=0)
        except Exception as e:
            err.append(e)
            continue
    try:
        test = pd.DataFrame(
            track_, columns=['Track_uri', 'Artist_uri', 'Album_uri'])

        test.rename(columns={'Track_uri': 'track_uri',
                    'Artist_uri': 'artist_uri', 'Album_uri': 'album_uri'}, inplace=True)

        audio_features.drop(
            columns=['type', 'uri', 'track_href', 'analysis_url'], axis=1, inplace=True)

        test = pd.merge(test, audio_features,
                        left_on="track_uri", right_on="id", how='outer')
        test = pd.merge(test, track_, left_on="track_uri",
                        right_on="Track_uri", how='outer')
        test = pd.merge(test, artist_, left_on="artist_uri",
                        right_on="Artist_uri", how='outer')

        test.rename(columns={'genres': 'Artist_genres'}, inplace=True)

        test.drop(columns=['Track_uri', 'Artist_uri_x',
                'Artist_uri_y', 'Album_uri', 'id'], axis=1, inplace=True)
        
        test=test.dropna(axis=0)
        test['Track_pop'] = test['Track_pop'].apply(lambda x: int(x/5))
        test['Artist_pop'] = test['Artist_pop'].apply(lambda x: int(x/5))
        test['Track_release_date'] = test['Track_release_date'].apply(lambda x: x.split('-')[0])
        test['Track_release_date'] = test['Track_release_date'].astype('int16')
        test['Track_release_date'] = test['Track_release_date'].apply(lambda x: int(x/50))

        test[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']] = test[[
            'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']].astype('float16')
        test[['duration_ms']] = test[['duration_ms']].astype('float32')
        test[['Track_release_date', 'Track_pop', 'Artist_pop']] = test[[
            'Track_release_date', 'Track_pop', 'Artist_pop']].astype('int8')
    except Exception as e:
        err.append(e)
    err.append('Finish extraction')
    return test,err,audio_features,track_,artist_

# %%
test,err,audio_features,track_,artist_=extract(track_ids_uni,artist_id_uni)

# %%
err
# Out:
# ['Start audio features extraction',
#  'Start track features extraction',
#  'Start artist features extraction',
#  'Finish extraction']

# %%
test.head()
# Out:
#                 track_uri              artist_uri               album_uri  \
# 0  2iJuuzV8P9Yz0VSurttIV5  085pc2PYOi8bGKj0PNjekA  6edYDxspt9uQj21mbAfFIb
# 1  1I8tHoNBFTuoJAlh4hfVVE  23fqKkggKUBHNkbKtXEls4  0uMIzWh1uEpHEBell4rlF8
# 2  6oJ6le65B3SEqPwMRNXWjY  23fqKkggKUBHNkbKtXEls4  4wquJImu8RtyEuDtIAsfcE
# 3  01aTsQoKoeXofSTvKuunzv  738wLrAtLtCtFOLvQBXOXp  2rqjmynngV4AmGoL1ZEuwM
# 4  3C0nOe05EIt1390bVABLyN  2DlGxzQSjYe5N6G9nkYghR  3sysiYphqNRQw7VKLCg1yE
#
#    danceability    energy   key  loudness  mode  speechiness  acousticness  \
# 0      0.771973  0.685059   5.0 -6.847656   1.0     0.069580      0.018997
# 1      0.704102  0.633789  11.0 -7.375000   0.0     0.042786      0.393066
# 2      0.692871  0.678223   8.0 -7.160156   1.0     0.032410      0.015099
# 3      0.723145  0.809082   7.0 -3.080078   0.0     0.062500      0.003460
# 4      0.729980  0.776855   3.0 -5.195312   0.0     0.049591      0.104980
#
#    instrumentalness  liveness   valence     tempo  duration_ms  \
# 0          0.000090  0.130981  0.500977  130.0000     283400.0
# 1          0.000032  0.095215  0.410889  113.9375     271640.0
# 2          0.000006  0.101013  0.404053  103.9375     228267.0
# 3          0.001230  0.564941  0.273926   98.0000     176561.0
# 4          0.000478  0.069092  0.575195  130.0000     284867.0
#
#    time_signature  Track_release_date  Track_pop  Artist_pop  \
# 0             4.0                  40         16          14
# 1             4.0                  40         15          15
# 2             4.0                  40         15          15
# 3             4.0                  40         15          15
# 4             4.0                  40         16          15
#
#                                        Artist_genres
# 0                                      dance_pop pop
# 1                   edm pop pop_dance tropical_house
# 2                   edm pop pop_dance tropical_house
# 3  dance_pop edm electro_house moombahton pop pop...
# 4                   dance_pop pop urban_contemporary

# %%
audio_features.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.772   0.685    5    -6.849     1       0.0696       0.01900
# 1         0.704   0.634   11    -7.374     0       0.0428       0.39300
# 2         0.723   0.809    7    -3.081     0       0.0625       0.00346
# 3         0.730   0.777    3    -5.194     0       0.0496       0.10500
# 4         0.595   0.784    1    -4.878     1       0.1020       0.21600
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0          0.000090    0.1310    0.501  130.033  2iJuuzV8P9Yz0VSurttIV5
# 1          0.000032    0.0952    0.411  113.927  1I8tHoNBFTuoJAlh4hfVVE
# 2          0.001230    0.5650    0.274   98.007  01aTsQoKoeXofSTvKuunzv
# 3          0.000478    0.0691    0.575  130.000  3C0nOe05EIt1390bVABLyN
# 4          0.000000    0.0608    0.479  124.111  5K6Ssv4Z3zRvxt0P6EKUAP
#
#    duration_ms  time_signature
# 0       283400               4
# 1       271640               4
# 2       176561               4
# 3       284867               4
# 4       183726               4

# %%
track_.head()
# Out:
#                 Track_uri Track_release_date  Track_pop  \
# 0  2iJuuzV8P9Yz0VSurttIV5         2013-01-01         82
# 0  1I8tHoNBFTuoJAlh4hfVVE         2016-05-13         79
# 0  01aTsQoKoeXofSTvKuunzv         2015-06-01         79
# 0  3C0nOe05EIt1390bVABLyN         2011-04-29         83
# 0  5K6Ssv4Z3zRvxt0P6EKUAP         2021-05-20         78
#
#                Artist_uri               Album_uri
# 0  085pc2PYOi8bGKj0PNjekA  6edYDxspt9uQj21mbAfFIb
# 0  23fqKkggKUBHNkbKtXEls4  0uMIzWh1uEpHEBell4rlF8
# 0  738wLrAtLtCtFOLvQBXOXp  2rqjmynngV4AmGoL1ZEuwM
# 0  2DlGxzQSjYe5N6G9nkYghR  3sysiYphqNRQw7VKLCg1yE
# 0  4sTQVOfp9vEMCemLw50sbu  6kBuGNoOGE7uiPhN82dcJ1

# %%
artist_.head()
# Out:
#                Artist_uri  Artist_pop  \
# 0  1Cs0zKBU1kc0i8ypK3B9ai          87
# 0  0TnOYISbd1XYRBk9myaseg          83
# 0  3v6Ji4uoWtKRkhuDUaxi9n          64
# 0  7CajNmpbOovFoOoasH2HaY          85
# 0  69GGBxA162lTqCwzJG5jLp          79
#
#                                               genres
# 0               big_room dance_pop edm pop pop_dance
# 0                        dance_pop miami_hip_hop pop
# 0                                                edm
# 0  dance_pop edm electro_house house pop pop_danc...
# 0                                                pop

# %%
test.head(1)
# Out:
#                 track_uri              artist_uri               album_uri  \
# 0  2iJuuzV8P9Yz0VSurttIV5  085pc2PYOi8bGKj0PNjekA  6edYDxspt9uQj21mbAfFIb
#
#    danceability    energy  key  loudness  mode  speechiness  acousticness  \
# 0      0.771973  0.685059  5.0 -6.847656   1.0      0.06958      0.018997
#
#    instrumentalness  liveness   valence  tempo  duration_ms  time_signature  \
# 0           0.00009  0.130981  0.500977  130.0     283400.0             4.0
#
#    Track_release_date  Track_pop  Artist_pop  Artist_genres
# 0                  40         16          14  dance_pop pop

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
import pickle

# %%
test['Artist_genres'] = test['Artist_genres'].apply(lambda x: x.split(" "))
tfidf = TfidfVectorizer(max_features=20)  
tfidf_matrix = tfidf.fit_transform(test['Artist_genres'].apply(lambda x: " ".join(x)))
genre_df = pd.DataFrame(tfidf_matrix.toarray())
genre_df.columns = ['genre' + "|" +i for i in tfidf.get_feature_names_out()]
genre_df = genre_df.astype('float16')

# %%
genre_df

# %%
test.drop(columns=['Artist_genres'], axis=1, inplace=True)
test = pd.concat([test.reset_index(drop=True),genre_df.reset_index(drop=True)], axis=1)

# %%
test.head(5)

# %%
index=0
for x in test.columns:
    print(f"{index} - {x}")
    index+=1
# Out:
# 0 - track_uri
# 1 - artist_uri
# 2 - album_uri
# 3 - danceability
# 4 - energy
# 5 - key
# 6 - loudness
# 7 - mode
# 8 - speechiness
# 9 - acousticness
# 10 - instrumentalness
# 11 - liveness
# 12 - valence
# 13 - tempo
# 14 - duration_ms
# 15 - time_signature
# 16 - Track_release_date
# 17 - Track_pop
# 18 - Artist_pop
# 19 - genre|dance_pop
# 20 - genre|dutch_edm
# 21 - genre|edm
# 22 - genre|electro_house
# 23 - genre|electronic_trap
# 24 - genre|german_dance
# 25 - genre|german_techno
# 26 - genre|house
# 27 - genre|miami_hip_hop
# 28 - genre|pop
# 29 - genre|pop_dance
# 30 - genre|pop_edm
# 31 - genre|pop_rap
# 32 - genre|progressive_electro_house
# 33 - genre|progressive_house
# 34 - genre|slap_house
# 35 - genre|trance
# 36 - genre|tropical_house
# 37 - genre|uk_dance
# 38 - genre|urban_contemporary

# %%
lendf=len(pd.read_csv('Streamlit/data/streamlit_data.csv',usecols=['track_uri']))

# %%
model="Model 1"

# %%
same_art=5

# %%
grow=test.copy()

# %%
Fresult = pd.DataFrame()
x = 1
for i in range(int(lendf/2), lendf+1, int(lendf/2)):
    try:
        df = pd.read_csv('Streamlit/data/streamlit_data.csv',names= col_name,dtype=dtypes,skiprows=x,nrows=i)
        #log.append('reading data frame chunks from {} to {}'.format(x,i))
    except Exception as e:
        print("Failed to load grow")
        # # log.append('Failed to load grow')
        # log.append(e)
    grow = grow[~grow['track_uri'].isin(df['track_uri'].values)]
    df = df[~df['track_uri'].isin(test['track_uri'].values)]
    df['Artist_genres'] = df['Artist_genres'].apply(lambda x: x.split(" "))
    tfidf_matrix = tfidf.transform(df['Artist_genres'].apply(lambda x: " ".join(x)))
    genre_df = pd.DataFrame(tfidf_matrix.toarray())
    genre_df.columns = ['genre' + "|" +i for i in tfidf.get_feature_names_out()]
    genre_df = genre_df.astype('float16')
    df.drop(columns=['Artist_genres'], axis=1, inplace=True)
    df = pd.concat([df.reset_index(drop=True),
                genre_df.reset_index(drop=True)], axis=1)
    del genre_df
    try:
        df.drop(columns=['genre|unknown'], axis=1, inplace=True)
        test.drop(columns=['genre|unknown'], axis=1, inplace=True)
    except:
        print("genre|unknown not found")
        # log.append('genre|unknown not found')
    # log.append('Scaling the data .....')
    if x == 1:
        sc = pickle.load(open('Streamlit/data/sc.sav','rb'))
        df.iloc[:, 3:19] = sc.transform(df.iloc[:, 3:19])
        test.iloc[:, 3:19] = sc.transform(test.iloc[:, 3:19])
        # log.append("Creating playlist vector")
        print("Creating playlist vector")
        playvec = pd.DataFrame(test.sum(axis=0)).T
    else:
        df.iloc[:, 3:19] = sc.transform(df.iloc[:, 3:19])
    x = i
    if model == 'Model 1':
        df['sim']=cosine_similarity((df.drop(['track_uri', 'artist_uri', 'album_uri'], axis = 1)),(playvec.drop(['track_uri', 'artist_uri', 'album_uri'], axis = 1)))
        df['sim2']=cosine_similarity(df.iloc[:,16:-1],playvec.iloc[:,16:])
        df['sim3']=cosine_similarity(df.iloc[:,19:-2],playvec.iloc[:,19:])
        df = df.sort_values(['sim3','sim2','sim'],ascending = False,kind='stable').groupby('artist_uri').head(same_art).head(50)
        Fresult = pd.concat([Fresult, df], axis=0)
        Fresult = Fresult.sort_values(['sim3', 'sim2', 'sim'],ascending=False,kind='stable')
        Fresult.drop_duplicates(subset=['track_uri'], inplace=True,keep='first')
        Fresult = Fresult.groupby('artist_uri').head(same_art).head(50)
    elif model == 'Model 2':
        df['sim'] = cosine_similarity(df.iloc[:, 3:16], playvec.iloc[:, 3:16])
        df['sim2'] = cosine_similarity(df.loc[:, df.columns.str.startswith('T') | df.columns.str.startswith('A')], playvec.loc[:, playvec.columns.str.startswith('T') | playvec.columns.str.startswith('A')])
        df['sim3'] = cosine_similarity(df.loc[:, df.columns.str.startswith('genre')], playvec.loc[:, playvec.columns.str.startswith('genre')])
        df['sim4'] = (df['sim']+df['sim2']+df['sim3'])/3
        df = df.sort_values(['sim4'], ascending=False,kind='stable').groupby('artist_uri').head(same_art).head(50)
        Fresult = pd.concat([Fresult, df], axis=0)
        Fresult = Fresult.sort_values(['sim4'], ascending=False,kind='stable')
        Fresult.drop_duplicates(subset=['track_uri'], inplace=True,keep='first')
        Fresult = Fresult.groupby('artist_uri').head(same_art).head(50)
# Out:
# genre|unknown not found
# Creating playlist vector
# c:\Users\mayan\Desktop\DS\honors_mp\Spotify-Recommendation-System\.venv\Lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# c:\Users\mayan\Desktop\DS\honors_mp\Spotify-Recommendation-System\.venv\Lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# genre|unknown not found
# c:\Users\mayan\Desktop\DS\honors_mp\Spotify-Recommendation-System\.venv\Lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)

# %%
df = pd.read_csv('Streamlit/data/streamlit_data.csv',names= col_name,dtype=dtypes,skiprows=1)

# %%
df['Track_release_date'].value_counts()
# Out:
# 40    93323
# 39    19980
# 38       81
# Name: Track_release_date, dtype: int64

# %%
import pickle

# %%
sc = pickle.load(open('Streamlit/data/sc.sav','rb'))
df.iloc[:, 3:19] = sc.transform(df.iloc[:, 3:19])

# %%
df.iloc[0]
# Out:
# track_uri                                        0UaMYEvWZi0ZqiDOoHU3YI
# artist_uri                                       2wIVse2owClT7go1WT98tk
# album_uri                                        6vV5UrXcfyQD1wu4Qo2I9K
# danceability                                                   0.914978
# energy                                                         0.812988
# key                                                            0.363636
# loudness                                                       0.845309
# mode                                                                0.0
# speechiness                                                    0.125761
# acousticness                                                   0.031219
# instrumentalness                                               0.006983
# liveness                                                       0.047089
# valence                                                        0.810059
# tempo                                                          0.529831
# duration_ms                                                    0.042088
# time_signature                                                      0.8
# Track_release_date                                                  1.0
# Track_pop                                                      0.764706
# Artist_pop                                                          0.7
# Artist_genres         dance_pop hip_hop hip_pop neo_soul pop_rap r&b...
# Name: 0, dtype: object

# %%
df.columns
# Out:
# Index(['track_uri', 'artist_uri', 'album_uri', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
#        'Track_release_date', 'Track_pop', 'Artist_pop', 'Artist_genres'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# track_uri                                        0UaMYEvWZi0ZqiDOoHU3YI
# artist_uri                                       2wIVse2owClT7go1WT98tk
# album_uri                                        6vV5UrXcfyQD1wu4Qo2I9K
# danceability                                                   0.914978
# energy                                                         0.812988
# key                                                            0.363636
# loudness                                                       0.845309
# mode                                                                0.0
# speechiness                                                    0.125761
# acousticness                                                   0.031219
# instrumentalness                                               0.006983
# liveness                                                       0.047089
# valence                                                        0.810059
# tempo                                                          0.529831
# duration_ms                                                    0.042088
# time_signature                                                      0.8
# Track_release_date                                                  1.0
# Track_pop                                                      0.764706
# Artist_pop                                                          0.7
# Artist_genres         dance_pop hip_hop hip_pop neo_soul pop_rap r&b...
# Name: 0, dtype: object

# %%
index=0
for x in df.columns:
    print(f"{index} - {x}")
    index+=1
# Out:
# 0 - track_uri
# 1 - artist_uri
# 2 - album_uri
# 3 - danceability
# 4 - energy
# 5 - key
# 6 - loudness
# 7 - mode
# 8 - speechiness
# 9 - acousticness
# 10 - instrumentalness
# 11 - liveness
# 12 - valence
# 13 - tempo
# 14 - duration_ms
# 15 - time_signature
# 16 - Track_release_date
# 17 - Track_pop
# 18 - Artist_pop
# 19 - genre|dance_pop
# 20 - genre|dutch_edm
# 21 - genre|edm
# 22 - genre|electro_house
# 23 - genre|electronic_trap
# 24 - genre|german_dance
# 25 - genre|german_techno
# 26 - genre|house
# 27 - genre|miami_hip_hop
# 28 - genre|pop
# 29 - genre|pop_dance
# 30 - genre|pop_edm
# 31 - genre|pop_rap
# 32 - genre|progressive_electro_house
# 33 - genre|progressive_house
# 34 - genre|slap_house
# 35 - genre|trance
# 36 - genre|tropical_house
# 37 - genre|uk_dance
# 38 - genre|urban_contemporary
# 39 - sim
# 40 - sim2
# 41 - sim3

# %%
index=0
for x in playvec.columns:
    print(f"{index} - {x}")
    index+=1
# Out:
# 0 - track_uri
# 1 - artist_uri
# 2 - album_uri
# 3 - danceability
# 4 - energy
# 5 - key
# 6 - loudness
# 7 - mode
# 8 - speechiness
# 9 - acousticness
# 10 - instrumentalness
# 11 - liveness
# 12 - valence
# 13 - tempo
# 14 - duration_ms
# 15 - time_signature
# 16 - Track_release_date
# 17 - Track_pop
# 18 - Artist_pop
# 19 - genre|dance_pop
# 20 - genre|dutch_edm
# 21 - genre|edm
# 22 - genre|electro_house
# 23 - genre|electronic_trap
# 24 - genre|german_dance
# 25 - genre|german_techno
# 26 - genre|house
# 27 - genre|miami_hip_hop
# 28 - genre|pop
# 29 - genre|pop_dance
# 30 - genre|pop_edm
# 31 - genre|pop_rap
# 32 - genre|progressive_electro_house
# 33 - genre|progressive_house
# 34 - genre|slap_house
# 35 - genre|trance
# 36 - genre|tropical_house
# 37 - genre|uk_dance
# 38 - genre|urban_contemporary

# %%
Fresult
# Out:
#                     track_uri              artist_uri               album_uri  \
# 14874  3eR23VReFzcdmS7TYCrhCe  23fqKkggKUBHNkbKtXEls4  0IUCAsckpNyV4wHKIHQawC
# 11235  07nH4ifBxUB4lZcsf44Brn  7CajNmpbOovFoOoasH2HaY  48zisMeiXniWLzOQghbPqS
# 19203  3ebXMykcMXOcLeJ9xZ17XH  60d24wfXkVzDSfLS6hyCjZ  2v9rQe4F8fVSh5v8bAq0jF
# 14363       0.350   0.608887   0.545898         0.575684  0.969268  0.984013
# 14359       0.350   0.608887   0.545898         0.575684  0.965204  0.984013
# 19217       0.350   0.608887   0.545898         0.575684  0.958473  0.984013
# 19212       0.350   0.608887   0.545898         0.575684  0.944106  0.984013
# 12404       0.325   0.608887   0.545898         0.575684  0.975679  0.983859
# 12389       0.325   0.608887   0.545898         0.575684  0.971168  0.983859
# 12680       0.325   0.608887   0.545898         0.575684  0.967064  0.983859
# 17521       0.375   0.608887   0.545898         0.575684  0.947335  0.981436
# 14365       0.350   0.608887   0.545898         0.575684  0.970968  0.981380
# 17202       0.350   0.608887   0.545898         0.575684  0.961256  0.981380
# 3026        0.375   0.608887   0.545898         0.575684  0.963291  0.978404
# 17203       0.350   0.608887   0.545898         0.575684  0.956065  0.978348
# 12686       0.325   0.608887   0.545898         0.575684  0.950552  0.978195
# 17529       0.375   0.608887   0.545898         0.575684  0.966199  0.974969
# 3033        0.375   0.608887   0.545898         0.575684  0.965224  0.974969
# 12682       0.325   0.608887   0.545898         0.575684  0.968676  0.974758
#
#            sim3
# 14874  0.988463
# 11235  0.988463
# 19203  0.988463
# 14866  0.988463
# 11237  0.988463
# 11230  0.988463
# 11232  0.988463
# 17663  0.988463
# 17671  0.988463
# 17669  0.988463
# 17680  0.988463
# 17678  0.988463
# 12380  0.988463
# 14870  0.988463
# 14888  0.988463
# 14880  0.988463
# 11250  0.988463
# 7374   0.988463
# 14360  0.988463
# 19204  0.988463
# 12381  0.988463
# 12677  0.988463
# 14362  0.988463
# 7376   0.988463
# 7384   0.988463
# 7375   0.988463
# 19213  0.988463
# 12385  0.988463
# 12681  0.988463
# 17524  0.988463
# 17523  0.988463
# 17522  0.988463
# 7377   0.988463
# 17204  0.988463
# 14363  0.988463
# 14359  0.988463
# 19217  0.988463
# 19212  0.988463
# 12404  0.988463
# 12389  0.988463
# 12680  0.988463
# 17521  0.988463
# 14365  0.988463
# 17202  0.988463
# 3026   0.988463
# 17203  0.988463
# 12686  0.988463
# 17529  0.988463
# 3033   0.988463
# 12682  0.988463
#
# [50 rows x 25 columns]

# %% [markdown]
# ## Cosine Similarity checking

# %%
data = {'A':[20,19,0], 'B': [25,25,0], 'C': [30,31,0],'D':[-5,5,-5],'E':[-10,10,-10],'F':[-20,20,-20],'G':[-40,40,-40]}

# %%
data2={'A':[20], 'B': [25], 'C': [30],'D':[-5],'E':[-10],'F':[-20],'G':[-40]}

# %%
egdf=pd.DataFrame(data)

# %%
egdf2=pd.DataFrame(data2)

# %%
egdf
# Out:
#     A   B   C  D   E   F   G
# 0  20  25  30 -5 -10 -20 -40
# 1  19  25  31  5  10  20  40
# 2   0   0   0 -5 -10 -20 -40

# %%
egdf2
# Out:
#     A   B   C  D   E   F   G
# 0  20  25  30 -5 -10 -20 -40

# %%
egdf.iloc[:,:].shape
# Out:
# (3, 7)

# %%
cosine_similarity(egdf.iloc[:,4:],egdf2.iloc[:,4:])
# Out:
# array([[ 1.],
#        [-1.],
#        [ 1.]])
